# %%
import json
import pandas as pd
import os
from random import seed, sample
import shutil

# %%
def load_metadata(metadata_path):
    """Load metadata from a JSON file and return a DataFrame."""
    with open(metadata_path) as f:
        metadata = json.load(f)
    df = pd.DataFrame.from_dict(metadata, orient='index')
    df.reset_index(inplace=True)
    df.rename(columns={'index': 'video_filename'}, inplace=True)
    return df

# %%
# Part 0
part0_path = '../../data/dfdc_train_part_11/metadata.json'
part0_df = load_metadata(part0_path)
part0_df
# Out:
#       video_filename label  split        original
# 0     qgqsgtekwl.mp4  FAKE  train  ztutsnlhtr.mp4
# 1     bahpguunin.mp4  FAKE  train  frczmdfzza.mp4
# 2     qekttcqtpm.mp4  FAKE  train  zesnphumru.mp4
# 3     zxuqoykuqj.mp4  FAKE  train  dovdrtvmbx.mp4
# 4     ztfjilznzu.mp4  REAL  train             NaN
# ...              ...   ...    ...             ...
# 2113  nrsqnrcidv.mp4  FAKE  train  thfzywypts.mp4
# 2114  hhmflhhbih.mp4  FAKE  train  jbgklqgife.mp4
# 2115  lkgamwbygt.mp4  FAKE  train  eipwxqahgp.mp4
# 2116  rgmllhylbj.mp4  FAKE  train  usnyozppis.mp4
# 2117  ddhijrstzr.mp4  REAL  train             NaN
#
# [2118 rows x 4 columns]

# %%
# Part 1
part1_path = '../../data/dfdc_train_part_12/metadata.json'
part1_df = load_metadata(part1_path)
part1_df
# Out:
#       video_filename label  split        original
# 0     ufucquemsr.mp4  FAKE  train  ioxuwhhvge.mp4
# 1     hzpeccyres.mp4  FAKE  train  guupwbnbzc.mp4
# 2     qlrzbtcbbh.mp4  FAKE  train  erufbzxadr.mp4
# 3     voztvddhnf.mp4  FAKE  train  pejtahlmir.mp4
# 4     hollmfvplq.mp4  FAKE  train  mpbvaumtlo.mp4
# ...              ...   ...    ...             ...
# 2220  zgvjfpzubp.mp4  REAL  train             NaN
# 2221  pnxmphjyyo.mp4  REAL  train             NaN
# 2222  oathlhqdnz.mp4  FAKE  train  wcdmpwfooh.mp4
# 2223  oexoavedkb.mp4  FAKE  train  zgvjfpzubp.mp4
# 2224  hmurwmhvsz.mp4  REAL  train             NaN
#
# [2225 rows x 4 columns]

# %%
# Part 2
part2_path = '../../data/dfdc_train_part_13/metadata.json'
part2_df = load_metadata(part2_path)
part2_df
# Out:
#       video_filename label  split        original
# 0     wxiboojdnq.mp4  FAKE  train  vncfwkhxmd.mp4
# 1     ojdrqflslr.mp4  FAKE  train  yaivbfubpr.mp4
# 2     dewhpxurks.mp4  FAKE  train  gakrxuhtfw.mp4
# 3     hcyyjbngyp.mp4  FAKE  train  zjcicdzech.mp4
# 4     jeejkkargi.mp4  FAKE  train  khybkobcmj.mp4
# ...              ...   ...    ...             ...
# 3689  vlrkfbqajs.mp4  REAL  train             NaN
# 3690  mdampijxqe.mp4  REAL  train             NaN
# 3691  plboestduy.mp4  REAL  train             NaN
# 3692  radyyavwaa.mp4  FAKE  train  galckcdeka.mp4
# 3693  zglgidpizh.mp4  FAKE  train  sianpqcthw.mp4
#
# [3694 rows x 4 columns]

# %%
# Part 3
part3_path = '../../data/dfdc_train_part_8/metadata.json'
part3_df = load_metadata(part3_path)
part3_df
# Out:
#       video_filename label  split        original
# 0     laihwpwiee.mp4  FAKE  train  aeysrmfmht.mp4
# 1     kzkqjyioqf.mp4  FAKE  train  ighgptshjh.mp4
# 2     gbfhqkesql.mp4  FAKE  train  dplfintlwc.mp4
# 3     ahrigbsxpt.mp4  FAKE  train  nonwqkyict.mp4
# 4     mwifzhcxkx.mp4  FAKE  train  vqybdfadtl.mp4
# ...              ...   ...    ...             ...
# 2468  vbyjwspnie.mp4  REAL  train             NaN
# 2469  suleggscox.mp4  REAL  train             NaN
# 2470  qytjmqkfhh.mp4  FAKE  train  vbyjwspnie.mp4
# 2471  oavrralgxd.mp4  FAKE  train  mbxblocpyw.mp4
# 2472  qurcxbznni.mp4  FAKE  train  rstlwzctdt.mp4
#
# [2473 rows x 4 columns]

# %%
# Part 4
part4_path = '../../data/dfdc_train_part_4/metadata.json'
part4_df = load_metadata(part4_path)
part4_df
# Out:
#       video_filename label  split        original
# 0     oyixebfpcl.mp4  FAKE  train  bgpoldvzrh.mp4
# 1     sayyjwtjol.mp4  REAL  train             NaN
# 2     qxbnmwwgzp.mp4  FAKE  train  kmyrnchata.mp4
# 3     puudvugxrl.mp4  REAL  train             NaN
# 4     shclgsfxtj.mp4  FAKE  train  bgpoldvzrh.mp4
# ...              ...   ...    ...             ...
# 1696  midpeunjaz.mp4  FAKE  train  xjabnijtoe.mp4
# 1697  cdawymhaak.mp4  FAKE  train  xxbunqmupn.mp4
# 1698  kyxmtfyceu.mp4  FAKE  train  hvmcslpaeu.mp4
# 1699  aahncigwte.mp4  REAL  train             NaN
# 1700  jdnizohssx.mp4  FAKE  train  xxbunqmupn.mp4
#
# [1701 rows x 4 columns]

# %%
def append_full_path(df, directory_path):
    """
    Adds the full path to each video based on 'video_filename'.

    Parameters:
    df (pd.DataFrame): DataFrame containing 'video_filename' column.
    directory_path (str): Directory path where the videos are located.

    Returns:
    pd.DataFrame: DataFrame with a new 'full_path' column.
    """
    # Normalize the directory path
    directory_path = os.path.normpath(directory_path)

    # Add the full path to each video based on 'video_filename'
    df['full_path'] = df['video_filename'].apply(lambda x: os.path.normpath(os.path.join(directory_path, x)))
    return df

# %%
part0_df = append_full_path(part0_df, "../../data/dfdc_train_part_11")
part0_df
# Out:
#       video_filename label  split        original  \
# 0     qgqsgtekwl.mp4  FAKE  train  ztutsnlhtr.mp4
# 1     bahpguunin.mp4  FAKE  train  frczmdfzza.mp4
# 2     qekttcqtpm.mp4  FAKE  train  zesnphumru.mp4
# 3     zxuqoykuqj.mp4  FAKE  train  dovdrtvmbx.mp4
# 4     ztfjilznzu.mp4  REAL  train             NaN
# ...              ...   ...    ...             ...
# 2113  nrsqnrcidv.mp4  FAKE  train  thfzywypts.mp4
# 2114  hhmflhhbih.mp4  FAKE  train  jbgklqgife.mp4
# 2115  lkgamwbygt.mp4  FAKE  train  eipwxqahgp.mp4
# 2116  rgmllhylbj.mp4  FAKE  train  usnyozppis.mp4
# 2117  ddhijrstzr.mp4  REAL  train             NaN
#
#                                          full_path
# 0     ..\..\data\dfdc_train_part_11\qgqsgtekwl.mp4
# 1     ..\..\data\dfdc_train_part_11\bahpguunin.mp4
# 2     ..\..\data\dfdc_train_part_11\qekttcqtpm.mp4
# 3     ..\..\data\dfdc_train_part_11\zxuqoykuqj.mp4
# 4     ..\..\data\dfdc_train_part_11\ztfjilznzu.mp4
# ...                                            ...
# 2113  ..\..\data\dfdc_train_part_11\nrsqnrcidv.mp4
# 2114  ..\..\data\dfdc_train_part_11\hhmflhhbih.mp4
# 2115  ..\..\data\dfdc_train_part_11\lkgamwbygt.mp4
# 2116  ..\..\data\dfdc_train_part_11\rgmllhylbj.mp4
# 2117  ..\..\data\dfdc_train_part_11\ddhijrstzr.mp4
#
# [2118 rows x 5 columns]

# %%
part1_df = append_full_path(part1_df, "../../data/dfdc_train_part_12")
part1_df
# Out:
#       video_filename label  split        original  \
# 0     ufucquemsr.mp4  FAKE  train  ioxuwhhvge.mp4
# 1     hzpeccyres.mp4  FAKE  train  guupwbnbzc.mp4
# 2     qlrzbtcbbh.mp4  FAKE  train  erufbzxadr.mp4
# 3     voztvddhnf.mp4  FAKE  train  pejtahlmir.mp4
# 4     hollmfvplq.mp4  FAKE  train  mpbvaumtlo.mp4
# ...              ...   ...    ...             ...
# 2220  zgvjfpzubp.mp4  REAL  train             NaN
# 2221  pnxmphjyyo.mp4  REAL  train             NaN
# 2222  oathlhqdnz.mp4  FAKE  train  wcdmpwfooh.mp4
# 2223  oexoavedkb.mp4  FAKE  train  zgvjfpzubp.mp4
# 2224  hmurwmhvsz.mp4  REAL  train             NaN
#
#                                          full_path
# 0     ..\..\data\dfdc_train_part_12\ufucquemsr.mp4
# 1     ..\..\data\dfdc_train_part_12\hzpeccyres.mp4
# 2     ..\..\data\dfdc_train_part_12\qlrzbtcbbh.mp4
# 3     ..\..\data\dfdc_train_part_12\voztvddhnf.mp4
# 4     ..\..\data\dfdc_train_part_12\hollmfvplq.mp4
# ...                                            ...
# 2220  ..\..\data\dfdc_train_part_12\zgvjfpzubp.mp4
# 2221  ..\..\data\dfdc_train_part_12\pnxmphjyyo.mp4
# 2222  ..\..\data\dfdc_train_part_12\oathlhqdnz.mp4
# 2223  ..\..\data\dfdc_train_part_12\oexoavedkb.mp4
# 2224  ..\..\data\dfdc_train_part_12\hmurwmhvsz.mp4
#
# [2225 rows x 5 columns]

# %%
part2_df = append_full_path(part2_df, "../../data/dfdc_train_part_13")
part2_df
# Out:
#       video_filename label  split        original  \
# 0     wxiboojdnq.mp4  FAKE  train  vncfwkhxmd.mp4
# 1     ojdrqflslr.mp4  FAKE  train  yaivbfubpr.mp4
# 2     dewhpxurks.mp4  FAKE  train  gakrxuhtfw.mp4
# 3     hcyyjbngyp.mp4  FAKE  train  zjcicdzech.mp4
# 4     jeejkkargi.mp4  FAKE  train  khybkobcmj.mp4
# ...              ...   ...    ...             ...
# 3689  vlrkfbqajs.mp4  REAL  train             NaN
# 3690  mdampijxqe.mp4  REAL  train             NaN
# 3691  plboestduy.mp4  REAL  train             NaN
# 3692  radyyavwaa.mp4  FAKE  train  galckcdeka.mp4
# 3693  zglgidpizh.mp4  FAKE  train  sianpqcthw.mp4
#
#                                          full_path
# 0     ..\..\data\dfdc_train_part_13\wxiboojdnq.mp4
# 1     ..\..\data\dfdc_train_part_13\ojdrqflslr.mp4
# 2     ..\..\data\dfdc_train_part_13\dewhpxurks.mp4
# 3     ..\..\data\dfdc_train_part_13\hcyyjbngyp.mp4
# 4     ..\..\data\dfdc_train_part_13\jeejkkargi.mp4
# ...                                            ...
# 3689  ..\..\data\dfdc_train_part_13\vlrkfbqajs.mp4
# 3690  ..\..\data\dfdc_train_part_13\mdampijxqe.mp4
# 3691  ..\..\data\dfdc_train_part_13\plboestduy.mp4
# 3692  ..\..\data\dfdc_train_part_13\radyyavwaa.mp4
# 3693  ..\..\data\dfdc_train_part_13\zglgidpizh.mp4
#
# [3694 rows x 5 columns]

# %%
part3_df = append_full_path(part3_df, "../../data/dfdc_train_part_3")
part3_df
# Out:
#       video_filename label  split        original  \
# 0     vngueqqcmz.mp4  FAKE  train  ghfnznqrvh.mp4
# 1     ieblyetiob.mp4  FAKE  train  tsvhwitvah.mp4
# 2     dnrpknwija.mp4  FAKE  train  ezfrcspzxw.mp4
# 3     zznanrtksj.mp4  FAKE  train  rozrjmrmeo.mp4
# 4     vdwoazrodt.mp4  FAKE  train  kytwyrusew.mp4
# ...              ...   ...    ...             ...
# 1450  hexyjykhvk.mp4  REAL  train             NaN
# 1451  twgobosowv.mp4  REAL  train             NaN
# 1452  ysvogisftd.mp4  FAKE  train  oikhytmnol.mp4
# 1453  hwaxcxpfxl.mp4  REAL  train             NaN
# 1454  iutieugpqx.mp4  REAL  train             NaN
#
#                                         full_path
# 0     ..\..\data\dfdc_train_part_3\vngueqqcmz.mp4
# 1     ..\..\data\dfdc_train_part_3\ieblyetiob.mp4
# 2     ..\..\data\dfdc_train_part_3\dnrpknwija.mp4
# 3     ..\..\data\dfdc_train_part_3\zznanrtksj.mp4
# 4     ..\..\data\dfdc_train_part_3\vdwoazrodt.mp4
# ...                                           ...
# 1450  ..\..\data\dfdc_train_part_3\hexyjykhvk.mp4
# 1451  ..\..\data\dfdc_train_part_3\twgobosowv.mp4
# 1452  ..\..\data\dfdc_train_part_3\ysvogisftd.mp4
# 1453  ..\..\data\dfdc_train_part_3\hwaxcxpfxl.mp4
# 1454  ..\..\data\dfdc_train_part_3\iutieugpqx.mp4
#
# [1455 rows x 5 columns]

# %%
part4_df = append_full_path(part4_df, "../../data/dfdc_train_part_4")
part4_df
# Out:
#       video_filename label  split        original  \
# 0     oyixebfpcl.mp4  FAKE  train  bgpoldvzrh.mp4
# 1     sayyjwtjol.mp4  REAL  train             NaN
# 2     qxbnmwwgzp.mp4  FAKE  train  kmyrnchata.mp4
# 3     puudvugxrl.mp4  REAL  train             NaN
# 4     shclgsfxtj.mp4  FAKE  train  bgpoldvzrh.mp4
# ...              ...   ...    ...             ...
# 1696  midpeunjaz.mp4  FAKE  train  xjabnijtoe.mp4
# 1697  cdawymhaak.mp4  FAKE  train  xxbunqmupn.mp4
# 1698  kyxmtfyceu.mp4  FAKE  train  hvmcslpaeu.mp4
# 1699  aahncigwte.mp4  REAL  train             NaN
# 1700  jdnizohssx.mp4  FAKE  train  xxbunqmupn.mp4
#
#                                         full_path
# 0     ..\..\data\dfdc_train_part_4\oyixebfpcl.mp4
# 1     ..\..\data\dfdc_train_part_4\sayyjwtjol.mp4
# 2     ..\..\data\dfdc_train_part_4\qxbnmwwgzp.mp4
# 3     ..\..\data\dfdc_train_part_4\puudvugxrl.mp4
# 4     ..\..\data\dfdc_train_part_4\shclgsfxtj.mp4
# ...                                           ...
# 1696  ..\..\data\dfdc_train_part_4\midpeunjaz.mp4
# 1697  ..\..\data\dfdc_train_part_4\cdawymhaak.mp4
# 1698  ..\..\data\dfdc_train_part_4\kyxmtfyceu.mp4
# 1699  ..\..\data\dfdc_train_part_4\aahncigwte.mp4
# 1700  ..\..\data\dfdc_train_part_4\jdnizohssx.mp4
#
# [1701 rows x 5 columns]

# %%
def create_balanced_dataset(dfs, dirs, random_state=None, print_stats=True):
    """
    Creates a balanced dataset by keeping all real videos and selecting the same number 
    of fake videos randomly across multiple input DataFrames. Optionally prints dataset statistics.

    Parameters:
    dfs (list of pd.DataFrame): List of input DataFrames.
    dirs (list of str): List of directory paths corresponding to the DataFrames.
    random_state (int, optional): Seed for reproducibility.
    print_stats (bool, optional): If True, prints label counts and total size.

    Returns:
    pd.DataFrame: A new balanced DataFrame with equal number of real and fake videos.
    """
    if random_state is not None:
        seed(random_state)

    # Concatenate all DataFrames into one
    combined_df = pd.concat(dfs, ignore_index=True)

    # Separate REAL and FAKE videos
    real_videos = combined_df[combined_df['label'] == 'REAL']
    fake_videos = combined_df[combined_df['label'] == 'FAKE']

    # Number of real videos to use for balancing with fake videos
    num_real = len(real_videos)

    # Randomly select the same number of fake videos
    fake_videos_sampled = fake_videos.sample(n=num_real, random_state=random_state)

    # Combine the real and sampled fake videos into a balanced DataFrame
    balanced_df = pd.concat([real_videos, fake_videos_sampled], ignore_index=True)

    # Shuffle the balanced dataset for randomness
    balanced_df = balanced_df.sample(frac=1, random_state=random_state).reset_index(drop=True)

    # Helper function to calculate video size based on the appropriate directory
    def get_video_size(row):
        video_filename = row['video_filename']
        # Determine the correct directory based on the original DataFrame index range
        for i, df in enumerate(dfs):
            if row.name < len(df):
                full_path = os.path.join(dirs[i], video_filename)
                break
        return os.path.getsize(full_path) if os.path.exists(full_path) else 0

    if print_stats:
        # Calculate total size of videos in the balanced DataFrame
        balanced_df['video_size_bytes'] = balanced_df.apply(get_video_size, axis=1)
        total_size_bytes = balanced_df['video_size_bytes'].sum()

        # Print statistics
        label_counts = balanced_df['label'].value_counts()
        print("Label Counts for Balanced DataFrame:")
        print(label_counts.to_string(), "\n")

        # Convert total size to GB
        total_size_gb = total_size_bytes / (1024 ** 3)  # Convert bytes to GB
        print(f"Total size of Balanced DataFrame: {total_size_gb:.2f} GB\n")

    return balanced_df

# %%
# dfs = [part0_df, part1_df, part2_df, part3_df, part4_df]
# dirs = ["../../data/dfdc_train_part_0", "../../data/dfdc_train_part_1", "../../data/dfdc_train_part_2", "../../data/dfdc_train_part_3", "../../data/dfdc_train_part_4"]
dfs = [part0_df, part1_df, part2_df]
dirs = ["../../data/dfdc_train_part_0", "../../data/dfdc_train_part_1", "../../data/dfdc_train_part_2"]
balanced_df = create_balanced_dataset(dfs, dirs, random_state=42)
# Out:
# Label Counts for Balanced DataFrame:
# label
# FAKE    1109
# REAL    1109
#
# Total size of Balanced DataFrame: 0.00 GB

# %%
def move_to_balanced_folder_and_create_metadata(balanced_df, destination_dir, metadata_file='metadata.json'):
    """
    Moves video files from the balanced DataFrame to a specified destination directory and creates a metadata JSON file.

    Parameters:
    balanced_df (pd.DataFrame): DataFrame containing video file paths to be moved.
    destination_dir (str): Path to the destination directory where files should be moved.
    metadata_file (str): Name of the metadata JSON file to be created.
    """
    # Create destination directory if it doesn't exist
    os.makedirs(destination_dir, exist_ok=True)

    # Prepare the metadata DataFrame
    metadata_df = balanced_df[['video_filename', 'label', 'original']].copy()

    # Create the metadata JSON file
    metadata_path = os.path.join(destination_dir, metadata_file)
    metadata_df.to_json(metadata_path, orient='records', lines=True)

    print(f"Metadata JSON file created at: {metadata_path}")

    # Move files to the new location
    for _, row in balanced_df.iterrows():
        video_full_path = row['full_path']  # Assuming this already contains the full path

        if os.path.exists(video_full_path):  # Check if the file exists
            # Get the filename
            filename = os.path.basename(video_full_path)
            # Define the new destination path
            new_location = os.path.join(destination_dir, filename)

            # Move the file to the new location
            shutil.move(video_full_path, new_location)
            print(f"Moved: {video_full_path} -> {new_location}")
        else:
            print(f"File not found: {video_full_path}")

# %%
destination_folder = "../../data/balanced_dataset"
move_to_balanced_folder_and_create_metadata(balanced_df, destination_folder)
# Out:
# Metadata JSON file created at: ../../data/balanced_dataset\metadata.json
# Moved: ..\..\data\dfdc_train_part_12\lbipvzwlut.mp4 -> ../../data/balanced_dataset\lbipvzwlut.mp4
# Moved: ..\..\data\dfdc_train_part_12\zverzcapzv.mp4 -> ../../data/balanced_dataset\zverzcapzv.mp4
# Moved: ..\..\data\dfdc_train_part_11\grbtvvjvhz.mp4 -> ../../data/balanced_dataset\grbtvvjvhz.mp4
# Moved: ..\..\data\dfdc_train_part_12\iylqacirzy.mp4 -> ../../data/balanced_dataset\iylqacirzy.mp4
# Moved: ..\..\data\dfdc_train_part_12\djylanzkqq.mp4 -> ../../data/balanced_dataset\djylanzkqq.mp4
# Moved: ..\..\data\dfdc_train_part_13\dvseunekna.mp4 -> ../../data/balanced_dataset\dvseunekna.mp4
# Moved: ..\..\data\dfdc_train_part_11\fmbmlagoiq.mp4 -> ../../data/balanced_dataset\fmbmlagoiq.mp4
# Moved: ..\..\data\dfdc_train_part_12\ffsfxbzlwg.mp4 -> ../../data/balanced_dataset\ffsfxbzlwg.mp4
# Moved: ..\..\data\dfdc_train_part_11\nwndlagvxh.mp4 -> ../../data/balanced_dataset\nwndlagvxh.mp4
# Moved: ..\..\data\dfdc_train_part_12\eaqxklixlu.mp4 -> ../../data/balanced_dataset\eaqxklixlu.mp4
# Moved: ..\..\data\dfdc_train_part_13\wjsftxrqzj.mp4 -> ../../data/balanced_dataset\wjsftxrqzj.mp4
# Moved: ..\..\data\dfdc_train_part_11\qhnegrdqcw.mp4 -> ../../data/balanced_dataset\qhnegrdqcw.mp4
# Moved: ..\..\data\dfdc_train_part_13\ogdlfceemp.mp4 -> ../../data/balanced_dataset\ogdlfceemp.mp4
# Moved: ..\..\data\dfdc_train_part_11\cffiwsldyw.mp4 -> ../../data/balanced_dataset\cffiwsldyw.mp4
# Moved: ..\..\data\dfdc_train_part_12\iqclpotodm.mp4 -> ../../data/balanced_dataset\iqclpotodm.mp4
# Moved: ..\..\data\dfdc_train_part_13\kpikqnizoz.mp4 -> ../../data/balanced_dataset\kpikqnizoz.mp4
# Moved: ..\..\data\dfdc_train_part_11\egzkwyqirh.mp4 -> ../../data/balanced_dataset\egzkwyqirh.mp4
# Moved: ..\..\data\dfdc_train_part_13\fseopnryum.mp4 -> ../../data/balanced_dataset\fseopnryum.mp4
# Moved: ..\..\data\dfdc_train_part_11\dlpirjuvwi.mp4 -> ../../data/balanced_dataset\dlpirjuvwi.mp4
# Moved: ..\..\data\dfdc_train_part_13\gkwigusybt.mp4 -> ../../data/balanced_dataset\gkwigusybt.mp4
# Moved: ..\..\data\dfdc_train_part_12\guupwbnbzc.mp4 -> ../../data/balanced_dataset\guupwbnbzc.mp4
# Moved: ..\..\data\dfdc_train_part_13\fkqagjuckk.mp4 -> ../../data/balanced_dataset\fkqagjuckk.mp4
# Moved: ..\..\data\dfdc_train_part_11\jrrwdwqjdg.mp4 -> ../../data/balanced_dataset\jrrwdwqjdg.mp4
# Moved: ..\..\data\dfdc_train_part_11\dhrzxytixv.mp4 -> ../../data/balanced_dataset\dhrzxytixv.mp4
# Moved: ..\..\data\dfdc_train_part_13\defrnleigv.mp4 -> ../../data/balanced_dataset\defrnleigv.mp4
# Moved: ..\..\data\dfdc_train_part_13\ziwcygqpgh.mp4 -> ../../data/balanced_dataset\ziwcygqpgh.mp4
# Moved: ..\..\data\dfdc_train_part_11\rxlcjaiijw.mp4 -> ../../data/balanced_dataset\rxlcjaiijw.mp4
# Moved: ..\..\data\dfdc_train_part_13\ceqohdbyfi.mp4 -> ../../data/balanced_dataset\ceqohdbyfi.mp4
# Moved: ..\..\data\dfdc_train_part_12\ihauvmnevo.mp4 -> ../../data/balanced_dataset\ihauvmnevo.mp4
# Moved: ..\..\data\dfdc_train_part_12\chjhbsexls.mp4 -> ../../data/balanced_dataset\chjhbsexls.mp4
# Moved: ..\..\data\dfdc_train_part_12\jzllaqyqkd.mp4 -> ../../data/balanced_dataset\jzllaqyqkd.mp4
# Moved: ..\..\data\dfdc_train_part_13\dbexdostck.mp4 -> ../../data/balanced_dataset\dbexdostck.mp4
# Moved: ..\..\data\dfdc_train_part_13\usenqorfbm.mp4 -> ../../data/balanced_dataset\usenqorfbm.mp4
# Moved: ..\..\data\dfdc_train_part_11\zczcdldtqi.mp4 -> ../../data/balanced_dataset\zczcdldtqi.mp4
# Moved: ..\..\data\dfdc_train_part_12\mqcsnkuzqy.mp4 -> ../../data/balanced_dataset\mqcsnkuzqy.mp4
# Moved: ..\..\data\dfdc_train_part_12\ybqowvqyhm.mp4 -> ../../data/balanced_dataset\ybqowvqyhm.mp4
# Moved: ..\..\data\dfdc_train_part_11\yjbnfyuuli.mp4 -> ../../data/balanced_dataset\yjbnfyuuli.mp4
# Moved: ..\..\data\dfdc_train_part_12\fbhtlcpupl.mp4 -> ../../data/balanced_dataset\fbhtlcpupl.mp4
# Moved: ..\..\data\dfdc_train_part_12\znevocgbpw.mp4 -> ../../data/balanced_dataset\znevocgbpw.mp4
# Moved: ..\..\data\dfdc_train_part_13\oghyyclecl.mp4 -> ../../data/balanced_dataset\oghyyclecl.mp4
# Moved: ..\..\data\dfdc_train_part_11\pjciuhedrj.mp4 -> ../../data/balanced_dataset\pjciuhedrj.mp4
# Moved: ..\..\data\dfdc_train_part_11\tsxuijektx.mp4 -> ../../data/balanced_dataset\tsxuijektx.mp4
# Moved: ..\..\data\dfdc_train_part_13\qlvxhguitr.mp4 -> ../../data/balanced_dataset\qlvxhguitr.mp4
# Moved: ..\..\data\dfdc_train_part_13\wnzfpgjkte.mp4 -> ../../data/balanced_dataset\wnzfpgjkte.mp4
# Moved: ..\..\data\dfdc_train_part_13\ilawvuwlse.mp4 -> ../../data/balanced_dataset\ilawvuwlse.mp4
# Moved: ..\..\data\dfdc_train_part_11\brfjxrbezo.mp4 -> ../../data/balanced_dataset\brfjxrbezo.mp4
# Moved: ..\..\data\dfdc_train_part_13\tupariqkuw.mp4 -> ../../data/balanced_dataset\tupariqkuw.mp4
# Moved: ..\..\data\dfdc_train_part_13\tzkxumuidc.mp4 -> ../../data/balanced_dataset\tzkxumuidc.mp4
# Moved: ..\..\data\dfdc_train_part_13\gjwgmqislt.mp4 -> ../../data/balanced_dataset\gjwgmqislt.mp4
# Moved: ..\..\data\dfdc_train_part_13\qhtdxgqrgc.mp4 -> ../../data/balanced_dataset\qhtdxgqrgc.mp4
# Moved: ..\..\data\dfdc_train_part_12\ozhhaoydlq.mp4 -> ../../data/balanced_dataset\ozhhaoydlq.mp4
# Moved: ..\..\data\dfdc_train_part_11\izanyxbfrw.mp4 -> ../../data/balanced_dataset\izanyxbfrw.mp4
# Moved: ..\..\data\dfdc_train_part_12\uorhfryoru.mp4 -> ../../data/balanced_dataset\uorhfryoru.mp4
# Moved: ..\..\data\dfdc_train_part_12\mfxbxghiff.mp4 -> ../../data/balanced_dataset\mfxbxghiff.mp4
# Moved: ..\..\data\dfdc_train_part_13\ddjllgeomh.mp4 -> ../../data/balanced_dataset\ddjllgeomh.mp4
# Moved: ..\..\data\dfdc_train_part_13\lreytwldez.mp4 -> ../../data/balanced_dataset\lreytwldez.mp4
# Moved: ..\..\data\dfdc_train_part_11\dbmpfxwtfw.mp4 -> ../../data/balanced_dataset\dbmpfxwtfw.mp4
# Moved: ..\..\data\dfdc_train_part_13\wuikplzxgc.mp4 -> ../../data/balanced_dataset\wuikplzxgc.mp4
# Moved: ..\..\data\dfdc_train_part_11\ixwjksvtxv.mp4 -> ../../data/balanced_dataset\ixwjksvtxv.mp4
# Moved: ..\..\data\dfdc_train_part_11\dehwqyosfb.mp4 -> ../../data/balanced_dataset\dehwqyosfb.mp4
# Moved: ..\..\data\dfdc_train_part_13\uambqlgxwt.mp4 -> ../../data/balanced_dataset\uambqlgxwt.mp4
# Moved: ..\..\data\dfdc_train_part_12\nacoxwjfls.mp4 -> ../../data/balanced_dataset\nacoxwjfls.mp4
# Moved: ..\..\data\dfdc_train_part_12\mctatxfyfv.mp4 -> ../../data/balanced_dataset\mctatxfyfv.mp4
# Moved: ..\..\data\dfdc_train_part_13\muonplikax.mp4 -> ../../data/balanced_dataset\muonplikax.mp4
# Moved: ..\..\data\dfdc_train_part_13\hxtryetzjf.mp4 -> ../../data/balanced_dataset\hxtryetzjf.mp4
# Moved: ..\..\data\dfdc_train_part_13\nwkqnloqad.mp4 -> ../../data/balanced_dataset\nwkqnloqad.mp4
# Moved: ..\..\data\dfdc_train_part_11\fvmhipsebc.mp4 -> ../../data/balanced_dataset\fvmhipsebc.mp4
# Moved: ..\..\data\dfdc_train_part_12\jzvphhwlqf.mp4 -> ../../data/balanced_dataset\jzvphhwlqf.mp4
# Moved: ..\..\data\dfdc_train_part_13\bziluffqhf.mp4 -> ../../data/balanced_dataset\bziluffqhf.mp4
# Moved: ..\..\data\dfdc_train_part_12\wgklnmklxb.mp4 -> ../../data/balanced_dataset\wgklnmklxb.mp4
# Moved: ..\..\data\dfdc_train_part_11\yoeetkfxec.mp4 -> ../../data/balanced_dataset\yoeetkfxec.mp4
# Moved: ..\..\data\dfdc_train_part_12\uswefjjphg.mp4 -> ../../data/balanced_dataset\uswefjjphg.mp4
# Moved: ..\..\data\dfdc_train_part_13\kxlxizoohe.mp4 -> ../../data/balanced_dataset\kxlxizoohe.mp4
# Moved: ..\..\data\dfdc_train_part_11\upjpywzofs.mp4 -> ../../data/balanced_dataset\upjpywzofs.mp4
# Moved: ..\..\data\dfdc_train_part_11\vgyftxulpj.mp4 -> ../../data/balanced_dataset\vgyftxulpj.mp4
# Moved: ..\..\data\dfdc_train_part_13\dfsddgovoo.mp4 -> ../../data/balanced_dataset\dfsddgovoo.mp4
# Moved: ..\..\data\dfdc_train_part_12\utfamtxcne.mp4 -> ../../data/balanced_dataset\utfamtxcne.mp4
# Moved: ..\..\data\dfdc_train_part_11\ahxnjolsip.mp4 -> ../../data/balanced_dataset\ahxnjolsip.mp4
# Moved: ..\..\data\dfdc_train_part_12\nhtkueolya.mp4 -> ../../data/balanced_dataset\nhtkueolya.mp4
# Moved: ..\..\data\dfdc_train_part_12\anukjnkojh.mp4 -> ../../data/balanced_dataset\anukjnkojh.mp4
# Moved: ..\..\data\dfdc_train_part_12\etheswuzvz.mp4 -> ../../data/balanced_dataset\etheswuzvz.mp4
# Moved: ..\..\data\dfdc_train_part_13\kznjyibisr.mp4 -> ../../data/balanced_dataset\kznjyibisr.mp4
# Moved: ..\..\data\dfdc_train_part_12\zbhlvhjjgt.mp4 -> ../../data/balanced_dataset\zbhlvhjjgt.mp4
# Moved: ..\..\data\dfdc_train_part_11\qgkqxjgjcj.mp4 -> ../../data/balanced_dataset\qgkqxjgjcj.mp4
# Moved: ..\..\data\dfdc_train_part_11\wlddznsbmi.mp4 -> ../../data/balanced_dataset\wlddznsbmi.mp4
# Moved: ..\..\data\dfdc_train_part_12\mjqtuozaey.mp4 -> ../../data/balanced_dataset\mjqtuozaey.mp4
# Moved: ..\..\data\dfdc_train_part_12\sbdevixeul.mp4 -> ../../data/balanced_dataset\sbdevixeul.mp4
# Moved: ..\..\data\dfdc_train_part_11\tbuuuamwak.mp4 -> ../../data/balanced_dataset\tbuuuamwak.mp4
# Moved: ..\..\data\dfdc_train_part_13\bicyhiobff.mp4 -> ../../data/balanced_dataset\bicyhiobff.mp4
# Moved: ..\..\data\dfdc_train_part_11\gcwuhlegud.mp4 -> ../../data/balanced_dataset\gcwuhlegud.mp4
# Moved: ..\..\data\dfdc_train_part_13\rlmhejztfu.mp4 -> ../../data/balanced_dataset\rlmhejztfu.mp4
# Moved: ..\..\data\dfdc_train_part_13\jbebjrmqiu.mp4 -> ../../data/balanced_dataset\jbebjrmqiu.mp4
# Moved: ..\..\data\dfdc_train_part_13\akndeedthv.mp4 -> ../../data/balanced_dataset\akndeedthv.mp4
# Moved: ..\..\data\dfdc_train_part_13\xrmslnoqku.mp4 -> ../../data/balanced_dataset\xrmslnoqku.mp4
# Moved: ..\..\data\dfdc_train_part_11\aqyvunegbf.mp4 -> ../../data/balanced_dataset\aqyvunegbf.mp4
# Moved: ..\..\data\dfdc_train_part_12\almduxqxkm.mp4 -> ../../data/balanced_dataset\almduxqxkm.mp4
# Moved: ..\..\data\dfdc_train_part_13\azzhmmoycu.mp4 -> ../../data/balanced_dataset\azzhmmoycu.mp4
# Moved: ..\..\data\dfdc_train_part_13\qpmovegayu.mp4 -> ../../data/balanced_dataset\qpmovegayu.mp4
# Moved: ..\..\data\dfdc_train_part_13\wxotqppgxr.mp4 -> ../../data/balanced_dataset\wxotqppgxr.mp4
# Moved: ..\..\data\dfdc_train_part_11\kmnboeohyo.mp4 -> ../../data/balanced_dataset\kmnboeohyo.mp4
# Moved: ..\..\data\dfdc_train_part_11\mfhqonawni.mp4 -> ../../data/balanced_dataset\mfhqonawni.mp4
# Moved: ..\..\data\dfdc_train_part_12\cvotzhernt.mp4 -> ../../data/balanced_dataset\cvotzhernt.mp4
# Moved: ..\..\data\dfdc_train_part_13\zdpmjrfctz.mp4 -> ../../data/balanced_dataset\zdpmjrfctz.mp4
# Moved: ..\..\data\dfdc_train_part_12\sejttfsefa.mp4 -> ../../data/balanced_dataset\sejttfsefa.mp4
# Moved: ..\..\data\dfdc_train_part_13\jddffgsfed.mp4 -> ../../data/balanced_dataset\jddffgsfed.mp4
# Moved: ..\..\data\dfdc_train_part_11\ukuajnxcgv.mp4 -> ../../data/balanced_dataset\ukuajnxcgv.mp4
# Moved: ..\..\data\dfdc_train_part_11\zrtaylibdt.mp4 -> ../../data/balanced_dataset\zrtaylibdt.mp4
# Moved: ..\..\data\dfdc_train_part_12\weyftpcbbz.mp4 -> ../../data/balanced_dataset\weyftpcbbz.mp4
# Moved: ..\..\data\dfdc_train_part_12\jprwurdarq.mp4 -> ../../data/balanced_dataset\jprwurdarq.mp4
# Moved: ..\..\data\dfdc_train_part_13\zvimoqxcnh.mp4 -> ../../data/balanced_dataset\zvimoqxcnh.mp4
# Moved: ..\..\data\dfdc_train_part_12\ifezphpbcj.mp4 -> ../../data/balanced_dataset\ifezphpbcj.mp4
# Moved: ..\..\data\dfdc_train_part_11\lmrksqgmty.mp4 -> ../../data/balanced_dataset\lmrksqgmty.mp4
# Moved: ..\..\data\dfdc_train_part_11\hpskrtuawv.mp4 -> ../../data/balanced_dataset\hpskrtuawv.mp4
# Moved: ..\..\data\dfdc_train_part_12\kygmgbcrjg.mp4 -> ../../data/balanced_dataset\kygmgbcrjg.mp4
# Moved: ..\..\data\dfdc_train_part_13\bgjghivhji.mp4 -> ../../data/balanced_dataset\bgjghivhji.mp4
# Moved: ..\..\data\dfdc_train_part_11\rlqfqgaoxx.mp4 -> ../../data/balanced_dataset\rlqfqgaoxx.mp4
# Moved: ..\..\data\dfdc_train_part_12\dkzinomdzy.mp4 -> ../../data/balanced_dataset\dkzinomdzy.mp4
# Moved: ..\..\data\dfdc_train_part_13\nzycclllqm.mp4 -> ../../data/balanced_dataset\nzycclllqm.mp4
# Moved: ..\..\data\dfdc_train_part_12\hgbosjbwer.mp4 -> ../../data/balanced_dataset\hgbosjbwer.mp4
# Moved: ..\..\data\dfdc_train_part_12\knbpqrlrei.mp4 -> ../../data/balanced_dataset\knbpqrlrei.mp4
# Moved: ..\..\data\dfdc_train_part_12\kwprqsipok.mp4 -> ../../data/balanced_dataset\kwprqsipok.mp4
# Moved: ..\..\data\dfdc_train_part_11\skbpwareru.mp4 -> ../../data/balanced_dataset\skbpwareru.mp4
# Moved: ..\..\data\dfdc_train_part_13\snbzzyhnpz.mp4 -> ../../data/balanced_dataset\snbzzyhnpz.mp4
# Moved: ..\..\data\dfdc_train_part_11\apgogdhmzd.mp4 -> ../../data/balanced_dataset\apgogdhmzd.mp4
# Moved: ..\..\data\dfdc_train_part_11\vmalpcczmq.mp4 -> ../../data/balanced_dataset\vmalpcczmq.mp4
# Moved: ..\..\data\dfdc_train_part_11\ztiooseaps.mp4 -> ../../data/balanced_dataset\ztiooseaps.mp4
# Moved: ..\..\data\dfdc_train_part_13\mhlqhnuycn.mp4 -> ../../data/balanced_dataset\mhlqhnuycn.mp4
# Moved: ..\..\data\dfdc_train_part_11\hhyxnwbuxm.mp4 -> ../../data/balanced_dataset\hhyxnwbuxm.mp4
# Moved: ..\..\data\dfdc_train_part_12\cefwujawid.mp4 -> ../../data/balanced_dataset\cefwujawid.mp4
# Moved: ..\..\data\dfdc_train_part_13\cqerqirksv.mp4 -> ../../data/balanced_dataset\cqerqirksv.mp4
# Moved: ..\..\data\dfdc_train_part_12\kplgwaqclf.mp4 -> ../../data/balanced_dataset\kplgwaqclf.mp4
# Moved: ..\..\data\dfdc_train_part_13\vlrkfbqajs.mp4 -> ../../data/balanced_dataset\vlrkfbqajs.mp4
# Moved: ..\..\data\dfdc_train_part_13\ymvlpjmixv.mp4 -> ../../data/balanced_dataset\ymvlpjmixv.mp4
# Moved: ..\..\data\dfdc_train_part_11\zqwzlnrofa.mp4 -> ../../data/balanced_dataset\zqwzlnrofa.mp4
# Moved: ..\..\data\dfdc_train_part_13\hkjnztvsmk.mp4 -> ../../data/balanced_dataset\hkjnztvsmk.mp4
# Moved: ..\..\data\dfdc_train_part_13\glkgaerynm.mp4 -> ../../data/balanced_dataset\glkgaerynm.mp4
# Moved: ..\..\data\dfdc_train_part_13\akibmagvog.mp4 -> ../../data/balanced_dataset\akibmagvog.mp4
# Moved: ..\..\data\dfdc_train_part_12\mbnzdxplie.mp4 -> ../../data/balanced_dataset\mbnzdxplie.mp4
# Moved: ..\..\data\dfdc_train_part_13\nxiecpzelr.mp4 -> ../../data/balanced_dataset\nxiecpzelr.mp4
# Moved: ..\..\data\dfdc_train_part_11\mldnrqmhfs.mp4 -> ../../data/balanced_dataset\mldnrqmhfs.mp4
# Moved: ..\..\data\dfdc_train_part_13\pnbdbcevqs.mp4 -> ../../data/balanced_dataset\pnbdbcevqs.mp4
# Moved: ..\..\data\dfdc_train_part_11\lhwpsnzmah.mp4 -> ../../data/balanced_dataset\lhwpsnzmah.mp4
# Moved: ..\..\data\dfdc_train_part_12\ifvsoxuelf.mp4 -> ../../data/balanced_dataset\ifvsoxuelf.mp4
# Moved: ..\..\data\dfdc_train_part_13\ankkfzsaoz.mp4 -> ../../data/balanced_dataset\ankkfzsaoz.mp4
# Moved: ..\..\data\dfdc_train_part_13\cdbjreoznw.mp4 -> ../../data/balanced_dataset\cdbjreoznw.mp4
# Moved: ..\..\data\dfdc_train_part_13\yjopklxubl.mp4 -> ../../data/balanced_dataset\yjopklxubl.mp4
# Moved: ..\..\data\dfdc_train_part_12\biccegbekb.mp4 -> ../../data/balanced_dataset\biccegbekb.mp4
# Moved: ..\..\data\dfdc_train_part_12\azbokmbobc.mp4 -> ../../data/balanced_dataset\azbokmbobc.mp4
# Moved: ..\..\data\dfdc_train_part_13\gfyhbcbqkf.mp4 -> ../../data/balanced_dataset\gfyhbcbqkf.mp4
# Moved: ..\..\data\dfdc_train_part_12\lxaffoifga.mp4 -> ../../data/balanced_dataset\lxaffoifga.mp4
# Moved: ..\..\data\dfdc_train_part_13\jzjibrcwkj.mp4 -> ../../data/balanced_dataset\jzjibrcwkj.mp4
# Moved: ..\..\data\dfdc_train_part_13\locbylfkoh.mp4 -> ../../data/balanced_dataset\locbylfkoh.mp4
# Moved: ..\..\data\dfdc_train_part_13\iinyfxufxx.mp4 -> ../../data/balanced_dataset\iinyfxufxx.mp4
# Moved: ..\..\data\dfdc_train_part_13\goxkxrugwy.mp4 -> ../../data/balanced_dataset\goxkxrugwy.mp4
# Moved: ..\..\data\dfdc_train_part_13\fpnfwgeeuj.mp4 -> ../../data/balanced_dataset\fpnfwgeeuj.mp4
# Moved: ..\..\data\dfdc_train_part_12\ldmdjnvkjb.mp4 -> ../../data/balanced_dataset\ldmdjnvkjb.mp4
# Moved: ..\..\data\dfdc_train_part_13\trbdicpeov.mp4 -> ../../data/balanced_dataset\trbdicpeov.mp4
# Moved: ..\..\data\dfdc_train_part_12\vwapfmxoyf.mp4 -> ../../data/balanced_dataset\vwapfmxoyf.mp4
# Moved: ..\..\data\dfdc_train_part_13\kscgfownjj.mp4 -> ../../data/balanced_dataset\kscgfownjj.mp4
# Moved: ..\..\data\dfdc_train_part_13\zgjuobyjvh.mp4 -> ../../data/balanced_dataset\zgjuobyjvh.mp4
# Moved: ..\..\data\dfdc_train_part_12\ljrgrzikxi.mp4 -> ../../data/balanced_dataset\ljrgrzikxi.mp4
# Moved: ..\..\data\dfdc_train_part_11\szeqeiitnx.mp4 -> ../../data/balanced_dataset\szeqeiitnx.mp4
# Moved: ..\..\data\dfdc_train_part_11\umvwfynjoo.mp4 -> ../../data/balanced_dataset\umvwfynjoo.mp4
# Moved: ..\..\data\dfdc_train_part_13\jrelmwwawy.mp4 -> ../../data/balanced_dataset\jrelmwwawy.mp4
# Moved: ..\..\data\dfdc_train_part_11\udxxviwfkw.mp4 -> ../../data/balanced_dataset\udxxviwfkw.mp4
# Moved: ..\..\data\dfdc_train_part_12\iylnbnwfhc.mp4 -> ../../data/balanced_dataset\iylnbnwfhc.mp4
# Moved: ..\..\data\dfdc_train_part_13\pzocwlihge.mp4 -> ../../data/balanced_dataset\pzocwlihge.mp4
# Moved: ..\..\data\dfdc_train_part_11\mrqdkngrde.mp4 -> ../../data/balanced_dataset\mrqdkngrde.mp4
# Moved: ..\..\data\dfdc_train_part_12\lfnvgnmsxx.mp4 -> ../../data/balanced_dataset\lfnvgnmsxx.mp4
# Moved: ..\..\data\dfdc_train_part_13\yqjaubfofy.mp4 -> ../../data/balanced_dataset\yqjaubfofy.mp4
# Moved: ..\..\data\dfdc_train_part_12\nhdirtckat.mp4 -> ../../data/balanced_dataset\nhdirtckat.mp4
# Moved: ..\..\data\dfdc_train_part_13\llauavbwur.mp4 -> ../../data/balanced_dataset\llauavbwur.mp4
# Moved: ..\..\data\dfdc_train_part_13\rtpzfzwnko.mp4 -> ../../data/balanced_dataset\rtpzfzwnko.mp4
# Moved: ..\..\data\dfdc_train_part_11\zfsjxtmgxc.mp4 -> ../../data/balanced_dataset\zfsjxtmgxc.mp4
# Moved: ..\..\data\dfdc_train_part_13\ditgqvducp.mp4 -> ../../data/balanced_dataset\ditgqvducp.mp4
# Moved: ..\..\data\dfdc_train_part_11\cuypznsdlz.mp4 -> ../../data/balanced_dataset\cuypznsdlz.mp4
# Moved: ..\..\data\dfdc_train_part_11\ptjgyuwsgh.mp4 -> ../../data/balanced_dataset\ptjgyuwsgh.mp4
# Moved: ..\..\data\dfdc_train_part_13\drxkxlcmto.mp4 -> ../../data/balanced_dataset\drxkxlcmto.mp4
# Moved: ..\..\data\dfdc_train_part_11\hvbnkquhzl.mp4 -> ../../data/balanced_dataset\hvbnkquhzl.mp4
# Moved: ..\..\data\dfdc_train_part_12\yqnsdfwelt.mp4 -> ../../data/balanced_dataset\yqnsdfwelt.mp4
# Moved: ..\..\data\dfdc_train_part_12\vmnsqsedbm.mp4 -> ../../data/balanced_dataset\vmnsqsedbm.mp4
# Moved: ..\..\data\dfdc_train_part_11\brnpejbjwh.mp4 -> ../../data/balanced_dataset\brnpejbjwh.mp4
# Moved: ..\..\data\dfdc_train_part_13\sejmzolvtv.mp4 -> ../../data/balanced_dataset\sejmzolvtv.mp4
# Moved: ..\..\data\dfdc_train_part_11\dovdrtvmbx.mp4 -> ../../data/balanced_dataset\dovdrtvmbx.mp4
# Moved: ..\..\data\dfdc_train_part_11\huowsesgyq.mp4 -> ../../data/balanced_dataset\huowsesgyq.mp4
# Moved: ..\..\data\dfdc_train_part_13\esqvscxctu.mp4 -> ../../data/balanced_dataset\esqvscxctu.mp4
# Moved: ..\..\data\dfdc_train_part_13\atewgdjqdl.mp4 -> ../../data/balanced_dataset\atewgdjqdl.mp4
# Moved: ..\..\data\dfdc_train_part_12\bdqrqgwytw.mp4 -> ../../data/balanced_dataset\bdqrqgwytw.mp4
# Moved: ..\..\data\dfdc_train_part_13\fejjwuoosa.mp4 -> ../../data/balanced_dataset\fejjwuoosa.mp4
# Moved: ..\..\data\dfdc_train_part_13\afugtpbwml.mp4 -> ../../data/balanced_dataset\afugtpbwml.mp4
# Moved: ..\..\data\dfdc_train_part_13\mnworobpfx.mp4 -> ../../data/balanced_dataset\mnworobpfx.mp4
# Moved: ..\..\data\dfdc_train_part_11\dfzwlayvoj.mp4 -> ../../data/balanced_dataset\dfzwlayvoj.mp4
# Moved: ..\..\data\dfdc_train_part_12\jhtafcntss.mp4 -> ../../data/balanced_dataset\jhtafcntss.mp4
# Moved: ..\..\data\dfdc_train_part_12\lgxesvqirp.mp4 -> ../../data/balanced_dataset\lgxesvqirp.mp4
# Moved: ..\..\data\dfdc_train_part_11\faypwmtdre.mp4 -> ../../data/balanced_dataset\faypwmtdre.mp4
# Moved: ..\..\data\dfdc_train_part_11\xcbckitcgh.mp4 -> ../../data/balanced_dataset\xcbckitcgh.mp4
# Moved: ..\..\data\dfdc_train_part_11\opsdpfofpl.mp4 -> ../../data/balanced_dataset\opsdpfofpl.mp4
# Moved: ..\..\data\dfdc_train_part_11\oqdpiefpij.mp4 -> ../../data/balanced_dataset\oqdpiefpij.mp4
# Moved: ..\..\data\dfdc_train_part_11\kewjgfclxa.mp4 -> ../../data/balanced_dataset\kewjgfclxa.mp4
# Moved: ..\..\data\dfdc_train_part_11\jrzphugdyd.mp4 -> ../../data/balanced_dataset\jrzphugdyd.mp4
# Moved: ..\..\data\dfdc_train_part_11\xeezdmaazr.mp4 -> ../../data/balanced_dataset\xeezdmaazr.mp4
# Moved: ..\..\data\dfdc_train_part_12\jfbnkogfbq.mp4 -> ../../data/balanced_dataset\jfbnkogfbq.mp4
# Moved: ..\..\data\dfdc_train_part_13\rcncybvyun.mp4 -> ../../data/balanced_dataset\rcncybvyun.mp4
# Moved: ..\..\data\dfdc_train_part_12\pkdhnsrrwz.mp4 -> ../../data/balanced_dataset\pkdhnsrrwz.mp4
# Moved: ..\..\data\dfdc_train_part_12\myjnthzkhv.mp4 -> ../../data/balanced_dataset\myjnthzkhv.mp4
# Moved: ..\..\data\dfdc_train_part_13\ewvelymojn.mp4 -> ../../data/balanced_dataset\ewvelymojn.mp4
# Moved: ..\..\data\dfdc_train_part_13\nmubvzvakr.mp4 -> ../../data/balanced_dataset\nmubvzvakr.mp4
# Moved: ..\..\data\dfdc_train_part_13\clvotgcjfe.mp4 -> ../../data/balanced_dataset\clvotgcjfe.mp4
# Moved: ..\..\data\dfdc_train_part_12\uweunfixll.mp4 -> ../../data/balanced_dataset\uweunfixll.mp4
# Moved: ..\..\data\dfdc_train_part_12\jdbztnbnif.mp4 -> ../../data/balanced_dataset\jdbztnbnif.mp4
# Moved: ..\..\data\dfdc_train_part_11\oyycqqgyov.mp4 -> ../../data/balanced_dataset\oyycqqgyov.mp4
# Moved: ..\..\data\dfdc_train_part_12\gvpsdogkiu.mp4 -> ../../data/balanced_dataset\gvpsdogkiu.mp4
# Moved: ..\..\data\dfdc_train_part_12\rnfchzufze.mp4 -> ../../data/balanced_dataset\rnfchzufze.mp4
# Moved: ..\..\data\dfdc_train_part_11\zesnphumru.mp4 -> ../../data/balanced_dataset\zesnphumru.mp4
# Moved: ..\..\data\dfdc_train_part_11\tvfyffofef.mp4 -> ../../data/balanced_dataset\tvfyffofef.mp4
# Moved: ..\..\data\dfdc_train_part_11\dmzblkdwkv.mp4 -> ../../data/balanced_dataset\dmzblkdwkv.mp4
# Moved: ..\..\data\dfdc_train_part_12\tfbsfycgfr.mp4 -> ../../data/balanced_dataset\tfbsfycgfr.mp4
# Moved: ..\..\data\dfdc_train_part_12\zkibdudrtn.mp4 -> ../../data/balanced_dataset\zkibdudrtn.mp4
# Moved: ..\..\data\dfdc_train_part_12\newgttpezs.mp4 -> ../../data/balanced_dataset\newgttpezs.mp4
# Moved: ..\..\data\dfdc_train_part_12\qskciwabjp.mp4 -> ../../data/balanced_dataset\qskciwabjp.mp4
# Moved: ..\..\data\dfdc_train_part_13\iwkufhbniy.mp4 -> ../../data/balanced_dataset\iwkufhbniy.mp4
# Moved: ..\..\data\dfdc_train_part_11\zeuqdyakda.mp4 -> ../../data/balanced_dataset\zeuqdyakda.mp4
# Moved: ..\..\data\dfdc_train_part_13\mdampijxqe.mp4 -> ../../data/balanced_dataset\mdampijxqe.mp4
# Moved: ..\..\data\dfdc_train_part_12\xsibczsnbr.mp4 -> ../../data/balanced_dataset\xsibczsnbr.mp4
# Moved: ..\..\data\dfdc_train_part_12\tdhbmxjdow.mp4 -> ../../data/balanced_dataset\tdhbmxjdow.mp4
# Moved: ..\..\data\dfdc_train_part_13\fmutbqbnsk.mp4 -> ../../data/balanced_dataset\fmutbqbnsk.mp4
# Moved: ..\..\data\dfdc_train_part_11\stgusymtgn.mp4 -> ../../data/balanced_dataset\stgusymtgn.mp4
# Moved: ..\..\data\dfdc_train_part_11\rfnwrnkokw.mp4 -> ../../data/balanced_dataset\rfnwrnkokw.mp4
# Moved: ..\..\data\dfdc_train_part_13\zisasluawf.mp4 -> ../../data/balanced_dataset\zisasluawf.mp4
# Moved: ..\..\data\dfdc_train_part_12\agiddwueyy.mp4 -> ../../data/balanced_dataset\agiddwueyy.mp4
# Moved: ..\..\data\dfdc_train_part_11\ztutsnlhtr.mp4 -> ../../data/balanced_dataset\ztutsnlhtr.mp4
# Moved: ..\..\data\dfdc_train_part_12\ivctdtckcn.mp4 -> ../../data/balanced_dataset\ivctdtckcn.mp4
# Moved: ..\..\data\dfdc_train_part_11\pvhhetqvpi.mp4 -> ../../data/balanced_dataset\pvhhetqvpi.mp4
# Moved: ..\..\data\dfdc_train_part_13\zhjkgdxdvv.mp4 -> ../../data/balanced_dataset\zhjkgdxdvv.mp4
# Moved: ..\..\data\dfdc_train_part_13\rvcujvmqxe.mp4 -> ../../data/balanced_dataset\rvcujvmqxe.mp4
# Moved: ..\..\data\dfdc_train_part_11\oxzmxkitwc.mp4 -> ../../data/balanced_dataset\oxzmxkitwc.mp4
# Moved: ..\..\data\dfdc_train_part_11\iujnlpzwuq.mp4 -> ../../data/balanced_dataset\iujnlpzwuq.mp4
# Moved: ..\..\data\dfdc_train_part_11\nyhvhszbuw.mp4 -> ../../data/balanced_dataset\nyhvhszbuw.mp4
# Moved: ..\..\data\dfdc_train_part_13\qbwxjdzjra.mp4 -> ../../data/balanced_dataset\qbwxjdzjra.mp4
# Moved: ..\..\data\dfdc_train_part_11\zrvnffustq.mp4 -> ../../data/balanced_dataset\zrvnffustq.mp4
# Moved: ..\..\data\dfdc_train_part_11\asjxofxzbd.mp4 -> ../../data/balanced_dataset\asjxofxzbd.mp4
# Moved: ..\..\data\dfdc_train_part_12\ruenzqaiww.mp4 -> ../../data/balanced_dataset\ruenzqaiww.mp4
# Moved: ..\..\data\dfdc_train_part_11\xklkkvztgc.mp4 -> ../../data/balanced_dataset\xklkkvztgc.mp4
# Moved: ..\..\data\dfdc_train_part_12\bseqngknsh.mp4 -> ../../data/balanced_dataset\bseqngknsh.mp4
# Moved: ..\..\data\dfdc_train_part_12\xcdcmgmqbl.mp4 -> ../../data/balanced_dataset\xcdcmgmqbl.mp4
# Moved: ..\..\data\dfdc_train_part_13\jejjxhajij.mp4 -> ../../data/balanced_dataset\jejjxhajij.mp4
# Moved: ..\..\data\dfdc_train_part_13\yneeguhhlb.mp4 -> ../../data/balanced_dataset\yneeguhhlb.mp4
# Moved: ..\..\data\dfdc_train_part_11\zweypycsww.mp4 -> ../../data/balanced_dataset\zweypycsww.mp4
# Moved: ..\..\data\dfdc_train_part_12\lkkdxlvtiq.mp4 -> ../../data/balanced_dataset\lkkdxlvtiq.mp4
# Moved: ..\..\data\dfdc_train_part_13\bofdhlwiof.mp4 -> ../../data/balanced_dataset\bofdhlwiof.mp4
# Moved: ..\..\data\dfdc_train_part_13\xnojggkrxt.mp4 -> ../../data/balanced_dataset\xnojggkrxt.mp4
# Moved: ..\..\data\dfdc_train_part_12\lnwblmvlmb.mp4 -> ../../data/balanced_dataset\lnwblmvlmb.mp4
# Moved: ..\..\data\dfdc_train_part_11\gqqngalilz.mp4 -> ../../data/balanced_dataset\gqqngalilz.mp4
# Moved: ..\..\data\dfdc_train_part_11\cixdftcnrs.mp4 -> ../../data/balanced_dataset\cixdftcnrs.mp4
# Moved: ..\..\data\dfdc_train_part_13\nfwqshwxgy.mp4 -> ../../data/balanced_dataset\nfwqshwxgy.mp4
# Moved: ..\..\data\dfdc_train_part_13\vmckfdrklb.mp4 -> ../../data/balanced_dataset\vmckfdrklb.mp4
# Moved: ..\..\data\dfdc_train_part_11\usbnyondzf.mp4 -> ../../data/balanced_dataset\usbnyondzf.mp4
# Moved: ..\..\data\dfdc_train_part_12\ihrydqwojs.mp4 -> ../../data/balanced_dataset\ihrydqwojs.mp4
# Moved: ..\..\data\dfdc_train_part_12\ngkxqtabyc.mp4 -> ../../data/balanced_dataset\ngkxqtabyc.mp4
# Moved: ..\..\data\dfdc_train_part_11\tkaxufvjgw.mp4 -> ../../data/balanced_dataset\tkaxufvjgw.mp4
# Moved: ..\..\data\dfdc_train_part_11\rzglourivm.mp4 -> ../../data/balanced_dataset\rzglourivm.mp4
# Moved: ..\..\data\dfdc_train_part_12\gvokuxhsbf.mp4 -> ../../data/balanced_dataset\gvokuxhsbf.mp4
# Moved: ..\..\data\dfdc_train_part_11\njanvyfzpv.mp4 -> ../../data/balanced_dataset\njanvyfzpv.mp4
# Moved: ..\..\data\dfdc_train_part_13\yrmbwlxunm.mp4 -> ../../data/balanced_dataset\yrmbwlxunm.mp4
# Moved: ..\..\data\dfdc_train_part_11\gxixautknf.mp4 -> ../../data/balanced_dataset\gxixautknf.mp4
# Moved: ..\..\data\dfdc_train_part_13\rhclxglqls.mp4 -> ../../data/balanced_dataset\rhclxglqls.mp4
# Moved: ..\..\data\dfdc_train_part_13\zlhvoufjou.mp4 -> ../../data/balanced_dataset\zlhvoufjou.mp4
# Moved: ..\..\data\dfdc_train_part_12\zkamlyqzao.mp4 -> ../../data/balanced_dataset\zkamlyqzao.mp4
# Moved: ..\..\data\dfdc_train_part_11\bxwswwesmk.mp4 -> ../../data/balanced_dataset\bxwswwesmk.mp4
# Moved: ..\..\data\dfdc_train_part_11\usnyozppis.mp4 -> ../../data/balanced_dataset\usnyozppis.mp4
# Moved: ..\..\data\dfdc_train_part_11\sevxalfpiw.mp4 -> ../../data/balanced_dataset\sevxalfpiw.mp4
# Moved: ..\..\data\dfdc_train_part_11\thkfrdqitc.mp4 -> ../../data/balanced_dataset\thkfrdqitc.mp4
# Moved: ..\..\data\dfdc_train_part_11\thfzywypts.mp4 -> ../../data/balanced_dataset\thfzywypts.mp4
# Moved: ..\..\data\dfdc_train_part_12\slkmlgxvqg.mp4 -> ../../data/balanced_dataset\slkmlgxvqg.mp4
# Moved: ..\..\data\dfdc_train_part_13\ylrcrtupec.mp4 -> ../../data/balanced_dataset\ylrcrtupec.mp4
# Moved: ..\..\data\dfdc_train_part_13\vlwylbdtqv.mp4 -> ../../data/balanced_dataset\vlwylbdtqv.mp4
# Moved: ..\..\data\dfdc_train_part_12\lkjgzcuaoi.mp4 -> ../../data/balanced_dataset\lkjgzcuaoi.mp4
# Moved: ..\..\data\dfdc_train_part_11\oproityyiy.mp4 -> ../../data/balanced_dataset\oproityyiy.mp4
# Moved: ..\..\data\dfdc_train_part_11\qirzbmqnww.mp4 -> ../../data/balanced_dataset\qirzbmqnww.mp4
# Moved: ..\..\data\dfdc_train_part_11\blruhiftcw.mp4 -> ../../data/balanced_dataset\blruhiftcw.mp4
# Moved: ..\..\data\dfdc_train_part_12\lwoohpengk.mp4 -> ../../data/balanced_dataset\lwoohpengk.mp4
# Moved: ..\..\data\dfdc_train_part_13\ireymetjjh.mp4 -> ../../data/balanced_dataset\ireymetjjh.mp4
# Moved: ..\..\data\dfdc_train_part_11\ffahlazvmr.mp4 -> ../../data/balanced_dataset\ffahlazvmr.mp4
# Moved: ..\..\data\dfdc_train_part_13\wtmhkoctjf.mp4 -> ../../data/balanced_dataset\wtmhkoctjf.mp4
# Moved: ..\..\data\dfdc_train_part_13\fxwnatanfs.mp4 -> ../../data/balanced_dataset\fxwnatanfs.mp4
# Moved: ..\..\data\dfdc_train_part_13\eeigpdutpu.mp4 -> ../../data/balanced_dataset\eeigpdutpu.mp4
# Moved: ..\..\data\dfdc_train_part_13\fomsttpqnm.mp4 -> ../../data/balanced_dataset\fomsttpqnm.mp4
# Moved: ..\..\data\dfdc_train_part_11\hdhurbyciy.mp4 -> ../../data/balanced_dataset\hdhurbyciy.mp4
# Moved: ..\..\data\dfdc_train_part_11\ufmuhoaetg.mp4 -> ../../data/balanced_dataset\ufmuhoaetg.mp4
# Moved: ..\..\data\dfdc_train_part_11\gvwqberjhs.mp4 -> ../../data/balanced_dataset\gvwqberjhs.mp4
# Moved: ..\..\data\dfdc_train_part_13\fpgnbvzycs.mp4 -> ../../data/balanced_dataset\fpgnbvzycs.mp4
# Moved: ..\..\data\dfdc_train_part_13\fluvmfflqo.mp4 -> ../../data/balanced_dataset\fluvmfflqo.mp4
# Moved: ..\..\data\dfdc_train_part_11\lggaanrbpk.mp4 -> ../../data/balanced_dataset\lggaanrbpk.mp4
# Moved: ..\..\data\dfdc_train_part_12\eljyfxrymd.mp4 -> ../../data/balanced_dataset\eljyfxrymd.mp4
# Moved: ..\..\data\dfdc_train_part_13\iagfwljuyl.mp4 -> ../../data/balanced_dataset\iagfwljuyl.mp4
# Moved: ..\..\data\dfdc_train_part_13\ukhqtirecl.mp4 -> ../../data/balanced_dataset\ukhqtirecl.mp4
# Moved: ..\..\data\dfdc_train_part_12\hbfojotjge.mp4 -> ../../data/balanced_dataset\hbfojotjge.mp4
# Moved: ..\..\data\dfdc_train_part_13\itucafenye.mp4 -> ../../data/balanced_dataset\itucafenye.mp4
# Moved: ..\..\data\dfdc_train_part_13\vslqeqyzee.mp4 -> ../../data/balanced_dataset\vslqeqyzee.mp4
# Moved: ..\..\data\dfdc_train_part_13\brrgojqquo.mp4 -> ../../data/balanced_dataset\brrgojqquo.mp4
# Moved: ..\..\data\dfdc_train_part_13\dxjkwqkpoy.mp4 -> ../../data/balanced_dataset\dxjkwqkpoy.mp4
# Moved: ..\..\data\dfdc_train_part_13\hdlpnaruhz.mp4 -> ../../data/balanced_dataset\hdlpnaruhz.mp4
# Moved: ..\..\data\dfdc_train_part_11\zhrjrsloix.mp4 -> ../../data/balanced_dataset\zhrjrsloix.mp4
# Moved: ..\..\data\dfdc_train_part_13\apifduvjkm.mp4 -> ../../data/balanced_dataset\apifduvjkm.mp4
# Moved: ..\..\data\dfdc_train_part_13\kdvzjnknxq.mp4 -> ../../data/balanced_dataset\kdvzjnknxq.mp4
# Moved: ..\..\data\dfdc_train_part_12\spnywzqwbd.mp4 -> ../../data/balanced_dataset\spnywzqwbd.mp4
# Moved: ..\..\data\dfdc_train_part_13\xyobbjywdf.mp4 -> ../../data/balanced_dataset\xyobbjywdf.mp4
# Moved: ..\..\data\dfdc_train_part_11\nnjmbcmolg.mp4 -> ../../data/balanced_dataset\nnjmbcmolg.mp4
# Moved: ..\..\data\dfdc_train_part_12\ruamngqldz.mp4 -> ../../data/balanced_dataset\ruamngqldz.mp4
# Moved: ..\..\data\dfdc_train_part_13\ygdaasvspv.mp4 -> ../../data/balanced_dataset\ygdaasvspv.mp4
# Moved: ..\..\data\dfdc_train_part_13\blsgycrkog.mp4 -> ../../data/balanced_dataset\blsgycrkog.mp4
# Moved: ..\..\data\dfdc_train_part_13\zevblyyjyz.mp4 -> ../../data/balanced_dataset\zevblyyjyz.mp4
# Moved: ..\..\data\dfdc_train_part_12\ooarfstzxd.mp4 -> ../../data/balanced_dataset\ooarfstzxd.mp4
# Moved: ..\..\data\dfdc_train_part_12\fdrrchsbbc.mp4 -> ../../data/balanced_dataset\fdrrchsbbc.mp4
# Moved: ..\..\data\dfdc_train_part_13\cwhowibuxc.mp4 -> ../../data/balanced_dataset\cwhowibuxc.mp4
# Moved: ..\..\data\dfdc_train_part_13\xdewpcxlmx.mp4 -> ../../data/balanced_dataset\xdewpcxlmx.mp4
# Moved: ..\..\data\dfdc_train_part_13\lujxppbtzk.mp4 -> ../../data/balanced_dataset\lujxppbtzk.mp4
# Moved: ..\..\data\dfdc_train_part_11\omaabqsujm.mp4 -> ../../data/balanced_dataset\omaabqsujm.mp4
# Moved: ..\..\data\dfdc_train_part_12\tbrrmhkbof.mp4 -> ../../data/balanced_dataset\tbrrmhkbof.mp4
# Moved: ..\..\data\dfdc_train_part_11\ppgwazusyl.mp4 -> ../../data/balanced_dataset\ppgwazusyl.mp4
# Moved: ..\..\data\dfdc_train_part_11\rmxvptssww.mp4 -> ../../data/balanced_dataset\rmxvptssww.mp4
# Moved: ..\..\data\dfdc_train_part_11\wjwgfkyjev.mp4 -> ../../data/balanced_dataset\wjwgfkyjev.mp4
# Moved: ..\..\data\dfdc_train_part_11\ipgikzjqty.mp4 -> ../../data/balanced_dataset\ipgikzjqty.mp4
# Moved: ..\..\data\dfdc_train_part_13\ihnykgbpuz.mp4 -> ../../data/balanced_dataset\ihnykgbpuz.mp4
# Moved: ..\..\data\dfdc_train_part_13\dushvzcaok.mp4 -> ../../data/balanced_dataset\dushvzcaok.mp4
# Moved: ..\..\data\dfdc_train_part_11\qxqktcxqpk.mp4 -> ../../data/balanced_dataset\qxqktcxqpk.mp4
# Moved: ..\..\data\dfdc_train_part_13\roiumkcfix.mp4 -> ../../data/balanced_dataset\roiumkcfix.mp4
# Moved: ..\..\data\dfdc_train_part_11\lcyfeiefju.mp4 -> ../../data/balanced_dataset\lcyfeiefju.mp4
# Moved: ..\..\data\dfdc_train_part_13\wgapnntrdc.mp4 -> ../../data/balanced_dataset\wgapnntrdc.mp4
# Moved: ..\..\data\dfdc_train_part_11\fynfkcgwri.mp4 -> ../../data/balanced_dataset\fynfkcgwri.mp4
# Moved: ..\..\data\dfdc_train_part_11\otudmwcikv.mp4 -> ../../data/balanced_dataset\otudmwcikv.mp4
# Moved: ..\..\data\dfdc_train_part_12\vciejrdkgf.mp4 -> ../../data/balanced_dataset\vciejrdkgf.mp4
# Moved: ..\..\data\dfdc_train_part_12\lqghtpbccp.mp4 -> ../../data/balanced_dataset\lqghtpbccp.mp4
# Moved: ..\..\data\dfdc_train_part_13\reccwuefen.mp4 -> ../../data/balanced_dataset\reccwuefen.mp4
# Moved: ..\..\data\dfdc_train_part_13\ztfurcavci.mp4 -> ../../data/balanced_dataset\ztfurcavci.mp4
# Moved: ..\..\data\dfdc_train_part_13\qakowhpqlm.mp4 -> ../../data/balanced_dataset\qakowhpqlm.mp4
# Moved: ..\..\data\dfdc_train_part_13\vnjrzywtrd.mp4 -> ../../data/balanced_dataset\vnjrzywtrd.mp4
# Moved: ..\..\data\dfdc_train_part_13\wvwmiaqwoe.mp4 -> ../../data/balanced_dataset\wvwmiaqwoe.mp4
# Moved: ..\..\data\dfdc_train_part_12\fmcqevzmhb.mp4 -> ../../data/balanced_dataset\fmcqevzmhb.mp4
# Moved: ..\..\data\dfdc_train_part_11\onygmnjhph.mp4 -> ../../data/balanced_dataset\onygmnjhph.mp4
# Moved: ..\..\data\dfdc_train_part_13\lrqhmruflh.mp4 -> ../../data/balanced_dataset\lrqhmruflh.mp4
# Moved: ..\..\data\dfdc_train_part_11\nwzvljonuc.mp4 -> ../../data/balanced_dataset\nwzvljonuc.mp4
# Moved: ..\..\data\dfdc_train_part_13\tyvehspuil.mp4 -> ../../data/balanced_dataset\tyvehspuil.mp4
# Moved: ..\..\data\dfdc_train_part_11\cqezovtiya.mp4 -> ../../data/balanced_dataset\cqezovtiya.mp4
# Moved: ..\..\data\dfdc_train_part_11\nrluhgnhdx.mp4 -> ../../data/balanced_dataset\nrluhgnhdx.mp4
# Moved: ..\..\data\dfdc_train_part_11\czmjdcggyj.mp4 -> ../../data/balanced_dataset\czmjdcggyj.mp4
# Moved: ..\..\data\dfdc_train_part_12\rmpcrrwhzv.mp4 -> ../../data/balanced_dataset\rmpcrrwhzv.mp4
# Moved: ..\..\data\dfdc_train_part_12\iuovlbhebm.mp4 -> ../../data/balanced_dataset\iuovlbhebm.mp4
# Moved: ..\..\data\dfdc_train_part_13\rqkorynhco.mp4 -> ../../data/balanced_dataset\rqkorynhco.mp4
# Moved: ..\..\data\dfdc_train_part_12\ykxuygbjwe.mp4 -> ../../data/balanced_dataset\ykxuygbjwe.mp4
# Moved: ..\..\data\dfdc_train_part_12\xiekprhlqw.mp4 -> ../../data/balanced_dataset\xiekprhlqw.mp4
# Moved: ..\..\data\dfdc_train_part_11\prypqfuqom.mp4 -> ../../data/balanced_dataset\prypqfuqom.mp4
# Moved: ..\..\data\dfdc_train_part_12\ptpwappdyx.mp4 -> ../../data/balanced_dataset\ptpwappdyx.mp4
# Moved: ..\..\data\dfdc_train_part_12\udhoamgxmx.mp4 -> ../../data/balanced_dataset\udhoamgxmx.mp4
# Moved: ..\..\data\dfdc_train_part_11\eaeulwiese.mp4 -> ../../data/balanced_dataset\eaeulwiese.mp4
# Moved: ..\..\data\dfdc_train_part_13\njkxkxfpux.mp4 -> ../../data/balanced_dataset\njkxkxfpux.mp4
# Moved: ..\..\data\dfdc_train_part_12\zlsqiyjmvt.mp4 -> ../../data/balanced_dataset\zlsqiyjmvt.mp4
# Moved: ..\..\data\dfdc_train_part_13\kabkawqwns.mp4 -> ../../data/balanced_dataset\kabkawqwns.mp4
# Moved: ..\..\data\dfdc_train_part_11\sgqruiabdi.mp4 -> ../../data/balanced_dataset\sgqruiabdi.mp4
# Moved: ..\..\data\dfdc_train_part_12\nbtskfzobv.mp4 -> ../../data/balanced_dataset\nbtskfzobv.mp4
# Moved: ..\..\data\dfdc_train_part_13\izhfjncnut.mp4 -> ../../data/balanced_dataset\izhfjncnut.mp4
# Moved: ..\..\data\dfdc_train_part_12\uvcmnjvwwg.mp4 -> ../../data/balanced_dataset\uvcmnjvwwg.mp4
# Moved: ..\..\data\dfdc_train_part_12\anjlmqmuaj.mp4 -> ../../data/balanced_dataset\anjlmqmuaj.mp4
# Moved: ..\..\data\dfdc_train_part_12\jjxwsknwdx.mp4 -> ../../data/balanced_dataset\jjxwsknwdx.mp4
# Moved: ..\..\data\dfdc_train_part_13\gxnmiqvuky.mp4 -> ../../data/balanced_dataset\gxnmiqvuky.mp4
# Moved: ..\..\data\dfdc_train_part_13\zsrqnmhgtv.mp4 -> ../../data/balanced_dataset\zsrqnmhgtv.mp4
# Moved: ..\..\data\dfdc_train_part_11\bafktkorci.mp4 -> ../../data/balanced_dataset\bafktkorci.mp4
# Moved: ..\..\data\dfdc_train_part_12\lfbgdlvhme.mp4 -> ../../data/balanced_dataset\lfbgdlvhme.mp4
# Moved: ..\..\data\dfdc_train_part_13\cjwbrvxbgb.mp4 -> ../../data/balanced_dataset\cjwbrvxbgb.mp4
# Moved: ..\..\data\dfdc_train_part_11\ymugvyxuka.mp4 -> ../../data/balanced_dataset\ymugvyxuka.mp4
# Moved: ..\..\data\dfdc_train_part_13\bowlklfabb.mp4 -> ../../data/balanced_dataset\bowlklfabb.mp4
# Moved: ..\..\data\dfdc_train_part_11\ehxxmfftom.mp4 -> ../../data/balanced_dataset\ehxxmfftom.mp4
# Moved: ..\..\data\dfdc_train_part_12\vqhpgdkvzv.mp4 -> ../../data/balanced_dataset\vqhpgdkvzv.mp4
# Moved: ..\..\data\dfdc_train_part_12\kbwquvelaz.mp4 -> ../../data/balanced_dataset\kbwquvelaz.mp4
# Moved: ..\..\data\dfdc_train_part_12\vtaagrckne.mp4 -> ../../data/balanced_dataset\vtaagrckne.mp4
# Moved: ..\..\data\dfdc_train_part_12\ekolzsqdzj.mp4 -> ../../data/balanced_dataset\ekolzsqdzj.mp4
# Moved: ..\..\data\dfdc_train_part_13\pwugzqrzqu.mp4 -> ../../data/balanced_dataset\pwugzqrzqu.mp4
# Moved: ..\..\data\dfdc_train_part_11\uyhkttlaiz.mp4 -> ../../data/balanced_dataset\uyhkttlaiz.mp4
# Moved: ..\..\data\dfdc_train_part_12\yiurgxbllb.mp4 -> ../../data/balanced_dataset\yiurgxbllb.mp4
# Moved: ..\..\data\dfdc_train_part_11\aphbjcscfn.mp4 -> ../../data/balanced_dataset\aphbjcscfn.mp4
# Moved: ..\..\data\dfdc_train_part_11\gzukcthgqg.mp4 -> ../../data/balanced_dataset\gzukcthgqg.mp4
# Moved: ..\..\data\dfdc_train_part_12\cdxykuskua.mp4 -> ../../data/balanced_dataset\cdxykuskua.mp4
# Moved: ..\..\data\dfdc_train_part_12\tjzisdorws.mp4 -> ../../data/balanced_dataset\tjzisdorws.mp4
# Moved: ..\..\data\dfdc_train_part_11\aruwupqwsc.mp4 -> ../../data/balanced_dataset\aruwupqwsc.mp4
# Moved: ..\..\data\dfdc_train_part_12\sirdjpbuka.mp4 -> ../../data/balanced_dataset\sirdjpbuka.mp4
# Moved: ..\..\data\dfdc_train_part_12\ielonfxgew.mp4 -> ../../data/balanced_dataset\ielonfxgew.mp4
# Moved: ..\..\data\dfdc_train_part_13\tcbjhkshde.mp4 -> ../../data/balanced_dataset\tcbjhkshde.mp4
# Moved: ..\..\data\dfdc_train_part_13\fkxppjofdq.mp4 -> ../../data/balanced_dataset\fkxppjofdq.mp4
# Moved: ..\..\data\dfdc_train_part_13\bjzkahdzig.mp4 -> ../../data/balanced_dataset\bjzkahdzig.mp4
# Moved: ..\..\data\dfdc_train_part_13\zwzwucpuus.mp4 -> ../../data/balanced_dataset\zwzwucpuus.mp4
# Moved: ..\..\data\dfdc_train_part_13\racokwyzky.mp4 -> ../../data/balanced_dataset\racokwyzky.mp4
# Moved: ..\..\data\dfdc_train_part_12\wfrxbuteyq.mp4 -> ../../data/balanced_dataset\wfrxbuteyq.mp4
# Moved: ..\..\data\dfdc_train_part_12\lbpfomllae.mp4 -> ../../data/balanced_dataset\lbpfomllae.mp4
# Moved: ..\..\data\dfdc_train_part_13\ueiowljylm.mp4 -> ../../data/balanced_dataset\ueiowljylm.mp4
# Moved: ..\..\data\dfdc_train_part_12\ntmrwnzvzt.mp4 -> ../../data/balanced_dataset\ntmrwnzvzt.mp4
# Moved: ..\..\data\dfdc_train_part_13\dklnixwbsm.mp4 -> ../../data/balanced_dataset\dklnixwbsm.mp4
# Moved: ..\..\data\dfdc_train_part_12\rwwdyjcoab.mp4 -> ../../data/balanced_dataset\rwwdyjcoab.mp4
# Moved: ..\..\data\dfdc_train_part_11\nrwoaqcgfm.mp4 -> ../../data/balanced_dataset\nrwoaqcgfm.mp4
# Moved: ..\..\data\dfdc_train_part_13\cqzbohnyip.mp4 -> ../../data/balanced_dataset\cqzbohnyip.mp4
# Moved: ..\..\data\dfdc_train_part_12\hbqncanmxj.mp4 -> ../../data/balanced_dataset\hbqncanmxj.mp4
# Moved: ..\..\data\dfdc_train_part_11\tkcbvnzhib.mp4 -> ../../data/balanced_dataset\tkcbvnzhib.mp4
# Moved: ..\..\data\dfdc_train_part_12\shvaqyduzg.mp4 -> ../../data/balanced_dataset\shvaqyduzg.mp4
# Moved: ..\..\data\dfdc_train_part_12\eltklzymmv.mp4 -> ../../data/balanced_dataset\eltklzymmv.mp4
# Moved: ..\..\data\dfdc_train_part_13\agcymsmqhj.mp4 -> ../../data/balanced_dataset\agcymsmqhj.mp4
# Moved: ..\..\data\dfdc_train_part_13\bdtwicokdu.mp4 -> ../../data/balanced_dataset\bdtwicokdu.mp4
# Moved: ..\..\data\dfdc_train_part_13\rpwnjppqqh.mp4 -> ../../data/balanced_dataset\rpwnjppqqh.mp4
# Moved: ..\..\data\dfdc_train_part_11\aevavjcuqq.mp4 -> ../../data/balanced_dataset\aevavjcuqq.mp4
# Moved: ..\..\data\dfdc_train_part_13\wniujdmckw.mp4 -> ../../data/balanced_dataset\wniujdmckw.mp4
# Moved: ..\..\data\dfdc_train_part_12\eyeqnbqamj.mp4 -> ../../data/balanced_dataset\eyeqnbqamj.mp4
# Moved: ..\..\data\dfdc_train_part_13\mkvgimuxbe.mp4 -> ../../data/balanced_dataset\mkvgimuxbe.mp4
# Moved: ..\..\data\dfdc_train_part_12\uvxgxixgmy.mp4 -> ../../data/balanced_dataset\uvxgxixgmy.mp4
# Moved: ..\..\data\dfdc_train_part_13\losgqyhukq.mp4 -> ../../data/balanced_dataset\losgqyhukq.mp4
# Moved: ..\..\data\dfdc_train_part_13\zpykipigtu.mp4 -> ../../data/balanced_dataset\zpykipigtu.mp4
# Moved: ..\..\data\dfdc_train_part_13\tyfwbskxbs.mp4 -> ../../data/balanced_dataset\tyfwbskxbs.mp4
# Moved: ..\..\data\dfdc_train_part_13\ugvugidcji.mp4 -> ../../data/balanced_dataset\ugvugidcji.mp4
# Moved: ..\..\data\dfdc_train_part_11\gwfgzoxmox.mp4 -> ../../data/balanced_dataset\gwfgzoxmox.mp4
# Moved: ..\..\data\dfdc_train_part_11\nrvhpzsvbo.mp4 -> ../../data/balanced_dataset\nrvhpzsvbo.mp4
# Moved: ..\..\data\dfdc_train_part_12\xkstqrneyc.mp4 -> ../../data/balanced_dataset\xkstqrneyc.mp4
# Moved: ..\..\data\dfdc_train_part_13\wwxugucmzx.mp4 -> ../../data/balanced_dataset\wwxugucmzx.mp4
# Moved: ..\..\data\dfdc_train_part_11\dmgooiimwk.mp4 -> ../../data/balanced_dataset\dmgooiimwk.mp4
# Moved: ..\..\data\dfdc_train_part_11\xrexmjcofm.mp4 -> ../../data/balanced_dataset\xrexmjcofm.mp4
# Moved: ..\..\data\dfdc_train_part_11\jbobnmshak.mp4 -> ../../data/balanced_dataset\jbobnmshak.mp4
# Moved: ..\..\data\dfdc_train_part_13\cjuxuxwrqs.mp4 -> ../../data/balanced_dataset\cjuxuxwrqs.mp4
# Moved: ..\..\data\dfdc_train_part_12\gphgxhyvni.mp4 -> ../../data/balanced_dataset\gphgxhyvni.mp4
# Moved: ..\..\data\dfdc_train_part_13\uxaufyecfa.mp4 -> ../../data/balanced_dataset\uxaufyecfa.mp4
# Moved: ..\..\data\dfdc_train_part_12\iydildurwm.mp4 -> ../../data/balanced_dataset\iydildurwm.mp4
# Moved: ..\..\data\dfdc_train_part_12\eanubsjnbk.mp4 -> ../../data/balanced_dataset\eanubsjnbk.mp4
# Moved: ..\..\data\dfdc_train_part_12\wbegjrceqs.mp4 -> ../../data/balanced_dataset\wbegjrceqs.mp4
# Moved: ..\..\data\dfdc_train_part_13\wfnfelbxnz.mp4 -> ../../data/balanced_dataset\wfnfelbxnz.mp4
# Moved: ..\..\data\dfdc_train_part_13\vgfrfuvdcy.mp4 -> ../../data/balanced_dataset\vgfrfuvdcy.mp4
# Moved: ..\..\data\dfdc_train_part_13\ybetmwdpzu.mp4 -> ../../data/balanced_dataset\ybetmwdpzu.mp4
# Moved: ..\..\data\dfdc_train_part_11\xsuthzpywj.mp4 -> ../../data/balanced_dataset\xsuthzpywj.mp4
# Moved: ..\..\data\dfdc_train_part_11\lzzlgtbvmx.mp4 -> ../../data/balanced_dataset\lzzlgtbvmx.mp4
# Moved: ..\..\data\dfdc_train_part_13\xbvjrriwxn.mp4 -> ../../data/balanced_dataset\xbvjrriwxn.mp4
# Moved: ..\..\data\dfdc_train_part_12\phdljoezcb.mp4 -> ../../data/balanced_dataset\phdljoezcb.mp4
# Moved: ..\..\data\dfdc_train_part_11\qybjhljexi.mp4 -> ../../data/balanced_dataset\qybjhljexi.mp4
# Moved: ..\..\data\dfdc_train_part_13\czyxcidvyj.mp4 -> ../../data/balanced_dataset\czyxcidvyj.mp4
# Moved: ..\..\data\dfdc_train_part_13\lguqmcyssv.mp4 -> ../../data/balanced_dataset\lguqmcyssv.mp4
# Moved: ..\..\data\dfdc_train_part_12\yyyqdyejwn.mp4 -> ../../data/balanced_dataset\yyyqdyejwn.mp4
# Moved: ..\..\data\dfdc_train_part_13\mmumsbwfzp.mp4 -> ../../data/balanced_dataset\mmumsbwfzp.mp4
# Moved: ..\..\data\dfdc_train_part_13\hjskhdglby.mp4 -> ../../data/balanced_dataset\hjskhdglby.mp4
# Moved: ..\..\data\dfdc_train_part_13\nliawulyhm.mp4 -> ../../data/balanced_dataset\nliawulyhm.mp4
# Moved: ..\..\data\dfdc_train_part_12\tyuneuphue.mp4 -> ../../data/balanced_dataset\tyuneuphue.mp4
# Moved: ..\..\data\dfdc_train_part_12\tezjtpctqs.mp4 -> ../../data/balanced_dataset\tezjtpctqs.mp4
# Moved: ..\..\data\dfdc_train_part_11\mhpgyqlaad.mp4 -> ../../data/balanced_dataset\mhpgyqlaad.mp4
# Moved: ..\..\data\dfdc_train_part_13\jxucddaulv.mp4 -> ../../data/balanced_dataset\jxucddaulv.mp4
# Moved: ..\..\data\dfdc_train_part_12\riosmbifsw.mp4 -> ../../data/balanced_dataset\riosmbifsw.mp4
# Moved: ..\..\data\dfdc_train_part_12\qppjjwvfbg.mp4 -> ../../data/balanced_dataset\qppjjwvfbg.mp4
# Moved: ..\..\data\dfdc_train_part_13\bhdekznjrb.mp4 -> ../../data/balanced_dataset\bhdekznjrb.mp4
# Moved: ..\..\data\dfdc_train_part_12\ohraninazv.mp4 -> ../../data/balanced_dataset\ohraninazv.mp4
# Moved: ..\..\data\dfdc_train_part_11\wxivyqkcuo.mp4 -> ../../data/balanced_dataset\wxivyqkcuo.mp4
# Moved: ..\..\data\dfdc_train_part_11\phkpguovju.mp4 -> ../../data/balanced_dataset\phkpguovju.mp4
# Moved: ..\..\data\dfdc_train_part_11\ybztbncgbq.mp4 -> ../../data/balanced_dataset\ybztbncgbq.mp4
# Moved: ..\..\data\dfdc_train_part_11\fmguyggvxv.mp4 -> ../../data/balanced_dataset\fmguyggvxv.mp4
# Moved: ..\..\data\dfdc_train_part_13\naqwmmjjva.mp4 -> ../../data/balanced_dataset\naqwmmjjva.mp4
# Moved: ..\..\data\dfdc_train_part_13\hlwitavnnd.mp4 -> ../../data/balanced_dataset\hlwitavnnd.mp4
# Moved: ..\..\data\dfdc_train_part_11\kmvsuicqeu.mp4 -> ../../data/balanced_dataset\kmvsuicqeu.mp4
# Moved: ..\..\data\dfdc_train_part_12\egidjdstrw.mp4 -> ../../data/balanced_dataset\egidjdstrw.mp4
# Moved: ..\..\data\dfdc_train_part_12\gpurfeajeg.mp4 -> ../../data/balanced_dataset\gpurfeajeg.mp4
# Moved: ..\..\data\dfdc_train_part_13\vrbzstiqjp.mp4 -> ../../data/balanced_dataset\vrbzstiqjp.mp4
# Moved: ..\..\data\dfdc_train_part_11\yflzmdpkab.mp4 -> ../../data/balanced_dataset\yflzmdpkab.mp4
# Moved: ..\..\data\dfdc_train_part_11\zcmezmfvvx.mp4 -> ../../data/balanced_dataset\zcmezmfvvx.mp4
# Moved: ..\..\data\dfdc_train_part_13\lqcotpccag.mp4 -> ../../data/balanced_dataset\lqcotpccag.mp4
# Moved: ..\..\data\dfdc_train_part_13\gsauowgqhs.mp4 -> ../../data/balanced_dataset\gsauowgqhs.mp4
# Moved: ..\..\data\dfdc_train_part_12\hoevrgmybf.mp4 -> ../../data/balanced_dataset\hoevrgmybf.mp4
# Moved: ..\..\data\dfdc_train_part_12\ahiinegyte.mp4 -> ../../data/balanced_dataset\ahiinegyte.mp4
# Moved: ..\..\data\dfdc_train_part_12\cnglddzyhs.mp4 -> ../../data/balanced_dataset\cnglddzyhs.mp4
# Moved: ..\..\data\dfdc_train_part_12\oykcgkszaa.mp4 -> ../../data/balanced_dataset\oykcgkszaa.mp4
# Moved: ..\..\data\dfdc_train_part_12\dagrpdryhv.mp4 -> ../../data/balanced_dataset\dagrpdryhv.mp4
# Moved: ..\..\data\dfdc_train_part_13\rougiapsti.mp4 -> ../../data/balanced_dataset\rougiapsti.mp4
# Moved: ..\..\data\dfdc_train_part_11\htjhybnluy.mp4 -> ../../data/balanced_dataset\htjhybnluy.mp4
# Moved: ..\..\data\dfdc_train_part_13\cfmhlrtsaf.mp4 -> ../../data/balanced_dataset\cfmhlrtsaf.mp4
# Moved: ..\..\data\dfdc_train_part_12\zrrrosmpxo.mp4 -> ../../data/balanced_dataset\zrrrosmpxo.mp4
# Moved: ..\..\data\dfdc_train_part_12\nubuehaydu.mp4 -> ../../data/balanced_dataset\nubuehaydu.mp4
# Moved: ..\..\data\dfdc_train_part_13\suevsrwyrq.mp4 -> ../../data/balanced_dataset\suevsrwyrq.mp4
# Moved: ..\..\data\dfdc_train_part_12\mofobetyqy.mp4 -> ../../data/balanced_dataset\mofobetyqy.mp4
# Moved: ..\..\data\dfdc_train_part_12\mygtpgseqd.mp4 -> ../../data/balanced_dataset\mygtpgseqd.mp4
# Moved: ..\..\data\dfdc_train_part_11\yaxrqafsok.mp4 -> ../../data/balanced_dataset\yaxrqafsok.mp4
# Moved: ..\..\data\dfdc_train_part_13\crtprwbbpd.mp4 -> ../../data/balanced_dataset\crtprwbbpd.mp4
# Moved: ..\..\data\dfdc_train_part_12\xnzgdeluhs.mp4 -> ../../data/balanced_dataset\xnzgdeluhs.mp4
# Moved: ..\..\data\dfdc_train_part_12\afxksdrgnc.mp4 -> ../../data/balanced_dataset\afxksdrgnc.mp4
# Moved: ..\..\data\dfdc_train_part_13\vqbbwvtywo.mp4 -> ../../data/balanced_dataset\vqbbwvtywo.mp4
# Moved: ..\..\data\dfdc_train_part_13\wwvcpyzdki.mp4 -> ../../data/balanced_dataset\wwvcpyzdki.mp4
# Moved: ..\..\data\dfdc_train_part_12\arfpvtvavs.mp4 -> ../../data/balanced_dataset\arfpvtvavs.mp4
# Moved: ..\..\data\dfdc_train_part_13\gdlctdrxzs.mp4 -> ../../data/balanced_dataset\gdlctdrxzs.mp4
# Moved: ..\..\data\dfdc_train_part_12\vvdngbqkjt.mp4 -> ../../data/balanced_dataset\vvdngbqkjt.mp4
# Moved: ..\..\data\dfdc_train_part_13\xofltpagqq.mp4 -> ../../data/balanced_dataset\xofltpagqq.mp4
# Moved: ..\..\data\dfdc_train_part_12\hpvahqsfvd.mp4 -> ../../data/balanced_dataset\hpvahqsfvd.mp4
# Moved: ..\..\data\dfdc_train_part_11\sdrhpnronp.mp4 -> ../../data/balanced_dataset\sdrhpnronp.mp4
# ...
# Moved: ..\..\data\dfdc_train_part_12\fclfsmueha.mp4 -> ../../data/balanced_dataset\fclfsmueha.mp4
# Moved: ..\..\data\dfdc_train_part_11\bhguavqyfj.mp4 -> ../../data/balanced_dataset\bhguavqyfj.mp4
# Moved: ..\..\data\dfdc_train_part_11\dzbgolojvf.mp4 -> ../../data/balanced_dataset\dzbgolojvf.mp4
# Moved: ..\..\data\dfdc_train_part_13\brnfoxrlfy.mp4 -> ../../data/balanced_dataset\brnfoxrlfy.mp4
# Moved: ..\..\data\dfdc_train_part_12\vigypenwpk.mp4 -> ../../data/balanced_dataset\vigypenwpk.mp4
# Moved: ..\..\data\dfdc_train_part_13\mscckixmjk.mp4 -> ../../data/balanced_dataset\mscckixmjk.mp4
# Moved: ..\..\data\dfdc_train_part_13\rgigbjpsis.mp4 -> ../../data/balanced_dataset\rgigbjpsis.mp4
# Moved: ..\..\data\dfdc_train_part_12\xihezvabxa.mp4 -> ../../data/balanced_dataset\xihezvabxa.mp4
# Moved: ..\..\data\dfdc_train_part_13\gjsirkzrwe.mp4 -> ../../data/balanced_dataset\gjsirkzrwe.mp4
# Moved: ..\..\data\dfdc_train_part_12\bvdoltmmat.mp4 -> ../../data/balanced_dataset\bvdoltmmat.mp4
# Moved: ..\..\data\dfdc_train_part_11\uyccyxegnj.mp4 -> ../../data/balanced_dataset\uyccyxegnj.mp4
# Moved: ..\..\data\dfdc_train_part_13\udecjhfbev.mp4 -> ../../data/balanced_dataset\udecjhfbev.mp4
# Moved: ..\..\data\dfdc_train_part_13\ahovbbmyls.mp4 -> ../../data/balanced_dataset\ahovbbmyls.mp4
# Moved: ..\..\data\dfdc_train_part_12\dhsoohbbeb.mp4 -> ../../data/balanced_dataset\dhsoohbbeb.mp4
# Moved: ..\..\data\dfdc_train_part_12\kkzeqaxrpt.mp4 -> ../../data/balanced_dataset\kkzeqaxrpt.mp4
# Moved: ..\..\data\dfdc_train_part_11\xfrfdspnox.mp4 -> ../../data/balanced_dataset\xfrfdspnox.mp4
# Moved: ..\..\data\dfdc_train_part_13\bzvhtmpwbd.mp4 -> ../../data/balanced_dataset\bzvhtmpwbd.mp4
# Moved: ..\..\data\dfdc_train_part_12\vtynsinghq.mp4 -> ../../data/balanced_dataset\vtynsinghq.mp4
# Moved: ..\..\data\dfdc_train_part_13\drqbnsabva.mp4 -> ../../data/balanced_dataset\drqbnsabva.mp4
# Moved: ..\..\data\dfdc_train_part_13\ovpbznkgev.mp4 -> ../../data/balanced_dataset\ovpbznkgev.mp4
# Moved: ..\..\data\dfdc_train_part_11\wslsgytaav.mp4 -> ../../data/balanced_dataset\wslsgytaav.mp4
# Moved: ..\..\data\dfdc_train_part_13\swchhjblce.mp4 -> ../../data/balanced_dataset\swchhjblce.mp4
# Moved: ..\..\data\dfdc_train_part_12\bearfhicjd.mp4 -> ../../data/balanced_dataset\bearfhicjd.mp4
# Moved: ..\..\data\dfdc_train_part_13\mntzlliqix.mp4 -> ../../data/balanced_dataset\mntzlliqix.mp4
# Moved: ..\..\data\dfdc_train_part_12\nfgfjxunyp.mp4 -> ../../data/balanced_dataset\nfgfjxunyp.mp4
# Moved: ..\..\data\dfdc_train_part_12\hedvoqehaw.mp4 -> ../../data/balanced_dataset\hedvoqehaw.mp4
# Moved: ..\..\data\dfdc_train_part_12\icvbwnjins.mp4 -> ../../data/balanced_dataset\icvbwnjins.mp4
# Moved: ..\..\data\dfdc_train_part_13\sdcjjvsgiz.mp4 -> ../../data/balanced_dataset\sdcjjvsgiz.mp4
# Moved: ..\..\data\dfdc_train_part_13\mulbnsfwui.mp4 -> ../../data/balanced_dataset\mulbnsfwui.mp4
# Moved: ..\..\data\dfdc_train_part_11\rskrntaywd.mp4 -> ../../data/balanced_dataset\rskrntaywd.mp4
# Moved: ..\..\data\dfdc_train_part_12\eeiaqkzsxi.mp4 -> ../../data/balanced_dataset\eeiaqkzsxi.mp4
# Moved: ..\..\data\dfdc_train_part_13\riqvfktrlj.mp4 -> ../../data/balanced_dataset\riqvfktrlj.mp4
# Moved: ..\..\data\dfdc_train_part_12\syujvyqdlu.mp4 -> ../../data/balanced_dataset\syujvyqdlu.mp4
# Moved: ..\..\data\dfdc_train_part_13\zriqxerfvh.mp4 -> ../../data/balanced_dataset\zriqxerfvh.mp4
# Moved: ..\..\data\dfdc_train_part_13\orbbzurpjs.mp4 -> ../../data/balanced_dataset\orbbzurpjs.mp4
# Moved: ..\..\data\dfdc_train_part_12\nndemqhngx.mp4 -> ../../data/balanced_dataset\nndemqhngx.mp4
# Moved: ..\..\data\dfdc_train_part_13\euijrempvm.mp4 -> ../../data/balanced_dataset\euijrempvm.mp4
# Moved: ..\..\data\dfdc_train_part_13\hrwgtkdgvh.mp4 -> ../../data/balanced_dataset\hrwgtkdgvh.mp4
# Moved: ..\..\data\dfdc_train_part_13\wfgeptqlkv.mp4 -> ../../data/balanced_dataset\wfgeptqlkv.mp4
# Moved: ..\..\data\dfdc_train_part_13\otqxsxinqo.mp4 -> ../../data/balanced_dataset\otqxsxinqo.mp4
# Moved: ..\..\data\dfdc_train_part_13\ytvaqzbbwt.mp4 -> ../../data/balanced_dataset\ytvaqzbbwt.mp4
# Moved: ..\..\data\dfdc_train_part_13\phppqqvzom.mp4 -> ../../data/balanced_dataset\phppqqvzom.mp4
# Moved: ..\..\data\dfdc_train_part_13\blapzzrmja.mp4 -> ../../data/balanced_dataset\blapzzrmja.mp4
# Moved: ..\..\data\dfdc_train_part_13\ltwpahbitr.mp4 -> ../../data/balanced_dataset\ltwpahbitr.mp4
# Moved: ..\..\data\dfdc_train_part_11\rauyrxosyg.mp4 -> ../../data/balanced_dataset\rauyrxosyg.mp4
# Moved: ..\..\data\dfdc_train_part_13\awfrfnpdas.mp4 -> ../../data/balanced_dataset\awfrfnpdas.mp4
# Moved: ..\..\data\dfdc_train_part_11\dmqzbafcfn.mp4 -> ../../data/balanced_dataset\dmqzbafcfn.mp4
# Moved: ..\..\data\dfdc_train_part_13\nenbnxxmrk.mp4 -> ../../data/balanced_dataset\nenbnxxmrk.mp4
# Moved: ..\..\data\dfdc_train_part_13\acmhexsysx.mp4 -> ../../data/balanced_dataset\acmhexsysx.mp4
# Moved: ..\..\data\dfdc_train_part_13\qoyfkewpyh.mp4 -> ../../data/balanced_dataset\qoyfkewpyh.mp4
# Moved: ..\..\data\dfdc_train_part_11\vderwgzgdx.mp4 -> ../../data/balanced_dataset\vderwgzgdx.mp4
# Moved: ..\..\data\dfdc_train_part_12\sirruhazin.mp4 -> ../../data/balanced_dataset\sirruhazin.mp4
# Moved: ..\..\data\dfdc_train_part_13\qsyvxfydbt.mp4 -> ../../data/balanced_dataset\qsyvxfydbt.mp4
# Moved: ..\..\data\dfdc_train_part_13\pyiglawaxn.mp4 -> ../../data/balanced_dataset\pyiglawaxn.mp4
# Moved: ..\..\data\dfdc_train_part_13\hgcqdpagpw.mp4 -> ../../data/balanced_dataset\hgcqdpagpw.mp4
# Moved: ..\..\data\dfdc_train_part_12\ynlucsymjj.mp4 -> ../../data/balanced_dataset\ynlucsymjj.mp4
# Moved: ..\..\data\dfdc_train_part_13\loaddqbplu.mp4 -> ../../data/balanced_dataset\loaddqbplu.mp4
# Moved: ..\..\data\dfdc_train_part_12\olwxxevrto.mp4 -> ../../data/balanced_dataset\olwxxevrto.mp4
# Moved: ..\..\data\dfdc_train_part_12\mkekdeolvn.mp4 -> ../../data/balanced_dataset\mkekdeolvn.mp4
# Moved: ..\..\data\dfdc_train_part_11\aokrlamaci.mp4 -> ../../data/balanced_dataset\aokrlamaci.mp4
# Moved: ..\..\data\dfdc_train_part_13\tucqgjzpip.mp4 -> ../../data/balanced_dataset\tucqgjzpip.mp4
# Moved: ..\..\data\dfdc_train_part_12\tfylliakig.mp4 -> ../../data/balanced_dataset\tfylliakig.mp4
# Moved: ..\..\data\dfdc_train_part_13\nwffuspknq.mp4 -> ../../data/balanced_dataset\nwffuspknq.mp4
# Moved: ..\..\data\dfdc_train_part_13\efdiwgnruf.mp4 -> ../../data/balanced_dataset\efdiwgnruf.mp4
# Moved: ..\..\data\dfdc_train_part_11\rxrtxejcpg.mp4 -> ../../data/balanced_dataset\rxrtxejcpg.mp4
# Moved: ..\..\data\dfdc_train_part_13\iroyrldewp.mp4 -> ../../data/balanced_dataset\iroyrldewp.mp4
# Moved: ..\..\data\dfdc_train_part_11\yzusjwgyav.mp4 -> ../../data/balanced_dataset\yzusjwgyav.mp4
# Moved: ..\..\data\dfdc_train_part_12\inpiiokedd.mp4 -> ../../data/balanced_dataset\inpiiokedd.mp4
# Moved: ..\..\data\dfdc_train_part_13\nfhriyhtji.mp4 -> ../../data/balanced_dataset\nfhriyhtji.mp4
# Moved: ..\..\data\dfdc_train_part_12\dstibundsx.mp4 -> ../../data/balanced_dataset\dstibundsx.mp4
# Moved: ..\..\data\dfdc_train_part_13\lbjaypbogz.mp4 -> ../../data/balanced_dataset\lbjaypbogz.mp4
# Moved: ..\..\data\dfdc_train_part_13\clykvdevmb.mp4 -> ../../data/balanced_dataset\clykvdevmb.mp4
# Moved: ..\..\data\dfdc_train_part_13\fnfzeexlaw.mp4 -> ../../data/balanced_dataset\fnfzeexlaw.mp4
# Moved: ..\..\data\dfdc_train_part_13\dateawnngx.mp4 -> ../../data/balanced_dataset\dateawnngx.mp4
# Moved: ..\..\data\dfdc_train_part_13\appnpveszq.mp4 -> ../../data/balanced_dataset\appnpveszq.mp4
# Moved: ..\..\data\dfdc_train_part_12\citpcmlvpy.mp4 -> ../../data/balanced_dataset\citpcmlvpy.mp4
# Moved: ..\..\data\dfdc_train_part_13\cqsyxoqcds.mp4 -> ../../data/balanced_dataset\cqsyxoqcds.mp4
# Moved: ..\..\data\dfdc_train_part_12\lqgolmlfvz.mp4 -> ../../data/balanced_dataset\lqgolmlfvz.mp4
# Moved: ..\..\data\dfdc_train_part_12\oxeujnjtsr.mp4 -> ../../data/balanced_dataset\oxeujnjtsr.mp4
# Moved: ..\..\data\dfdc_train_part_13\kjvczswcgw.mp4 -> ../../data/balanced_dataset\kjvczswcgw.mp4
# Moved: ..\..\data\dfdc_train_part_13\zmlqlldrzf.mp4 -> ../../data/balanced_dataset\zmlqlldrzf.mp4
# Moved: ..\..\data\dfdc_train_part_11\gsrvfdzmsq.mp4 -> ../../data/balanced_dataset\gsrvfdzmsq.mp4
# Moved: ..\..\data\dfdc_train_part_13\aitoprvlda.mp4 -> ../../data/balanced_dataset\aitoprvlda.mp4
# Moved: ..\..\data\dfdc_train_part_13\jucvtcykma.mp4 -> ../../data/balanced_dataset\jucvtcykma.mp4
# Moved: ..\..\data\dfdc_train_part_12\tysrnftddc.mp4 -> ../../data/balanced_dataset\tysrnftddc.mp4
# Moved: ..\..\data\dfdc_train_part_12\pejtahlmir.mp4 -> ../../data/balanced_dataset\pejtahlmir.mp4
# Moved: ..\..\data\dfdc_train_part_11\plczaniyed.mp4 -> ../../data/balanced_dataset\plczaniyed.mp4
# Moved: ..\..\data\dfdc_train_part_12\bglsrppmtk.mp4 -> ../../data/balanced_dataset\bglsrppmtk.mp4
# Moved: ..\..\data\dfdc_train_part_11\pdwsngffox.mp4 -> ../../data/balanced_dataset\pdwsngffox.mp4
# Moved: ..\..\data\dfdc_train_part_13\tiexcrjlgt.mp4 -> ../../data/balanced_dataset\tiexcrjlgt.mp4
# Moved: ..\..\data\dfdc_train_part_13\qipufogxbv.mp4 -> ../../data/balanced_dataset\qipufogxbv.mp4
# Moved: ..\..\data\dfdc_train_part_11\jtbdyxjnnv.mp4 -> ../../data/balanced_dataset\jtbdyxjnnv.mp4
# Moved: ..\..\data\dfdc_train_part_13\xzchpjydkn.mp4 -> ../../data/balanced_dataset\xzchpjydkn.mp4
# Moved: ..\..\data\dfdc_train_part_13\xijwzghfsv.mp4 -> ../../data/balanced_dataset\xijwzghfsv.mp4
# Moved: ..\..\data\dfdc_train_part_11\mzukjtldcu.mp4 -> ../../data/balanced_dataset\mzukjtldcu.mp4
# Moved: ..\..\data\dfdc_train_part_12\dbglpvkptp.mp4 -> ../../data/balanced_dataset\dbglpvkptp.mp4
# Moved: ..\..\data\dfdc_train_part_12\apscureryf.mp4 -> ../../data/balanced_dataset\apscureryf.mp4
# Moved: ..\..\data\dfdc_train_part_12\zjatoyujpi.mp4 -> ../../data/balanced_dataset\zjatoyujpi.mp4
# Moved: ..\..\data\dfdc_train_part_12\xbnxqnchxn.mp4 -> ../../data/balanced_dataset\xbnxqnchxn.mp4
# Moved: ..\..\data\dfdc_train_part_13\tjbqmyaimq.mp4 -> ../../data/balanced_dataset\tjbqmyaimq.mp4
# Moved: ..\..\data\dfdc_train_part_13\aqqaabjicv.mp4 -> ../../data/balanced_dataset\aqqaabjicv.mp4
# Moved: ..\..\data\dfdc_train_part_13\agvfchxufj.mp4 -> ../../data/balanced_dataset\agvfchxufj.mp4
# Moved: ..\..\data\dfdc_train_part_13\jicspspkbz.mp4 -> ../../data/balanced_dataset\jicspspkbz.mp4
# Moved: ..\..\data\dfdc_train_part_11\iahkeegnay.mp4 -> ../../data/balanced_dataset\iahkeegnay.mp4
# Moved: ..\..\data\dfdc_train_part_13\qujevbdicn.mp4 -> ../../data/balanced_dataset\qujevbdicn.mp4
# Moved: ..\..\data\dfdc_train_part_11\mbgbxqvxfl.mp4 -> ../../data/balanced_dataset\mbgbxqvxfl.mp4
# Moved: ..\..\data\dfdc_train_part_12\xhhkfqmuzx.mp4 -> ../../data/balanced_dataset\xhhkfqmuzx.mp4
# Moved: ..\..\data\dfdc_train_part_13\yetoyrfijk.mp4 -> ../../data/balanced_dataset\yetoyrfijk.mp4
# Moved: ..\..\data\dfdc_train_part_13\bnkpyfsvhy.mp4 -> ../../data/balanced_dataset\bnkpyfsvhy.mp4
# Moved: ..\..\data\dfdc_train_part_12\kntguwshwb.mp4 -> ../../data/balanced_dataset\kntguwshwb.mp4
# Moved: ..\..\data\dfdc_train_part_11\epwvvqsutn.mp4 -> ../../data/balanced_dataset\epwvvqsutn.mp4
# Moved: ..\..\data\dfdc_train_part_11\yanzsjwhrb.mp4 -> ../../data/balanced_dataset\yanzsjwhrb.mp4
# Moved: ..\..\data\dfdc_train_part_11\uojmmyhkuw.mp4 -> ../../data/balanced_dataset\uojmmyhkuw.mp4
# Moved: ..\..\data\dfdc_train_part_13\vgttrdzwyd.mp4 -> ../../data/balanced_dataset\vgttrdzwyd.mp4
# Moved: ..\..\data\dfdc_train_part_13\yjoebjlwkq.mp4 -> ../../data/balanced_dataset\yjoebjlwkq.mp4
# Moved: ..\..\data\dfdc_train_part_12\qiflakrrwc.mp4 -> ../../data/balanced_dataset\qiflakrrwc.mp4
# Moved: ..\..\data\dfdc_train_part_13\qipuoiuveu.mp4 -> ../../data/balanced_dataset\qipuoiuveu.mp4
# Moved: ..\..\data\dfdc_train_part_11\nttkjjshnb.mp4 -> ../../data/balanced_dataset\nttkjjshnb.mp4
# Moved: ..\..\data\dfdc_train_part_12\jhspiyddlk.mp4 -> ../../data/balanced_dataset\jhspiyddlk.mp4
# Moved: ..\..\data\dfdc_train_part_11\mqdiuiaqff.mp4 -> ../../data/balanced_dataset\mqdiuiaqff.mp4
# Moved: ..\..\data\dfdc_train_part_13\zaunbinekr.mp4 -> ../../data/balanced_dataset\zaunbinekr.mp4
# Moved: ..\..\data\dfdc_train_part_13\zqdlvewthj.mp4 -> ../../data/balanced_dataset\zqdlvewthj.mp4
# Moved: ..\..\data\dfdc_train_part_13\elwbzzkzse.mp4 -> ../../data/balanced_dataset\elwbzzkzse.mp4
# Moved: ..\..\data\dfdc_train_part_13\tqxxjgaudi.mp4 -> ../../data/balanced_dataset\tqxxjgaudi.mp4
# Moved: ..\..\data\dfdc_train_part_13\ynvaljmyhd.mp4 -> ../../data/balanced_dataset\ynvaljmyhd.mp4
# Moved: ..\..\data\dfdc_train_part_12\fruavxnszz.mp4 -> ../../data/balanced_dataset\fruavxnszz.mp4
# Moved: ..\..\data\dfdc_train_part_11\wkyftsfazg.mp4 -> ../../data/balanced_dataset\wkyftsfazg.mp4
# Moved: ..\..\data\dfdc_train_part_11\vqbyxeiuzk.mp4 -> ../../data/balanced_dataset\vqbyxeiuzk.mp4
# Moved: ..\..\data\dfdc_train_part_12\ecqfzguvwy.mp4 -> ../../data/balanced_dataset\ecqfzguvwy.mp4
# Moved: ..\..\data\dfdc_train_part_13\tcodtwcppn.mp4 -> ../../data/balanced_dataset\tcodtwcppn.mp4
# Moved: ..\..\data\dfdc_train_part_13\zcuvkwpspq.mp4 -> ../../data/balanced_dataset\zcuvkwpspq.mp4
# Moved: ..\..\data\dfdc_train_part_12\ronwdhfyxm.mp4 -> ../../data/balanced_dataset\ronwdhfyxm.mp4
# Moved: ..\..\data\dfdc_train_part_11\fkqkixrhhn.mp4 -> ../../data/balanced_dataset\fkqkixrhhn.mp4
# Moved: ..\..\data\dfdc_train_part_11\cfpmhnphqc.mp4 -> ../../data/balanced_dataset\cfpmhnphqc.mp4
# Moved: ..\..\data\dfdc_train_part_11\fbaowuyagg.mp4 -> ../../data/balanced_dataset\fbaowuyagg.mp4
# Moved: ..\..\data\dfdc_train_part_12\jyvlalljen.mp4 -> ../../data/balanced_dataset\jyvlalljen.mp4
# Moved: ..\..\data\dfdc_train_part_11\ynsxzcicxv.mp4 -> ../../data/balanced_dataset\ynsxzcicxv.mp4
# Moved: ..\..\data\dfdc_train_part_13\mhwzrcjgcu.mp4 -> ../../data/balanced_dataset\mhwzrcjgcu.mp4
# Moved: ..\..\data\dfdc_train_part_13\ypgynzbshp.mp4 -> ../../data/balanced_dataset\ypgynzbshp.mp4
# Moved: ..\..\data\dfdc_train_part_12\alebgijlzb.mp4 -> ../../data/balanced_dataset\alebgijlzb.mp4
# Moved: ..\..\data\dfdc_train_part_13\ryjofphcjc.mp4 -> ../../data/balanced_dataset\ryjofphcjc.mp4
# Moved: ..\..\data\dfdc_train_part_12\jdvzqjihud.mp4 -> ../../data/balanced_dataset\jdvzqjihud.mp4
# Moved: ..\..\data\dfdc_train_part_13\qkkubsdlzn.mp4 -> ../../data/balanced_dataset\qkkubsdlzn.mp4
# Moved: ..\..\data\dfdc_train_part_11\umsjbpjqjx.mp4 -> ../../data/balanced_dataset\umsjbpjqjx.mp4
# Moved: ..\..\data\dfdc_train_part_12\rzcxmxpdiu.mp4 -> ../../data/balanced_dataset\rzcxmxpdiu.mp4
# Moved: ..\..\data\dfdc_train_part_13\uziohtecjc.mp4 -> ../../data/balanced_dataset\uziohtecjc.mp4
# Moved: ..\..\data\dfdc_train_part_13\gurkxerekr.mp4 -> ../../data/balanced_dataset\gurkxerekr.mp4
# Moved: ..\..\data\dfdc_train_part_11\zganfnadhh.mp4 -> ../../data/balanced_dataset\zganfnadhh.mp4
# Moved: ..\..\data\dfdc_train_part_13\lnkbhiqfqc.mp4 -> ../../data/balanced_dataset\lnkbhiqfqc.mp4
# Moved: ..\..\data\dfdc_train_part_13\owvxxmuceg.mp4 -> ../../data/balanced_dataset\owvxxmuceg.mp4
# Moved: ..\..\data\dfdc_train_part_11\dieoechqok.mp4 -> ../../data/balanced_dataset\dieoechqok.mp4
# Moved: ..\..\data\dfdc_train_part_11\nigwzriyci.mp4 -> ../../data/balanced_dataset\nigwzriyci.mp4
# Moved: ..\..\data\dfdc_train_part_13\uvccplpsoe.mp4 -> ../../data/balanced_dataset\uvccplpsoe.mp4
# Moved: ..\..\data\dfdc_train_part_13\llyaoxunsb.mp4 -> ../../data/balanced_dataset\llyaoxunsb.mp4
# Moved: ..\..\data\dfdc_train_part_11\qkklqzcdkx.mp4 -> ../../data/balanced_dataset\qkklqzcdkx.mp4
# Moved: ..\..\data\dfdc_train_part_11\rddzwabube.mp4 -> ../../data/balanced_dataset\rddzwabube.mp4
# Moved: ..\..\data\dfdc_train_part_12\cznwglxzxz.mp4 -> ../../data/balanced_dataset\cznwglxzxz.mp4
# Moved: ..\..\data\dfdc_train_part_11\htqmwqohyq.mp4 -> ../../data/balanced_dataset\htqmwqohyq.mp4
# Moved: ..\..\data\dfdc_train_part_12\kskooyetsh.mp4 -> ../../data/balanced_dataset\kskooyetsh.mp4
# Moved: ..\..\data\dfdc_train_part_13\xqhwinqcxd.mp4 -> ../../data/balanced_dataset\xqhwinqcxd.mp4
# Moved: ..\..\data\dfdc_train_part_12\rpohehwnrk.mp4 -> ../../data/balanced_dataset\rpohehwnrk.mp4
# Moved: ..\..\data\dfdc_train_part_12\svlxzardad.mp4 -> ../../data/balanced_dataset\svlxzardad.mp4
# Moved: ..\..\data\dfdc_train_part_13\bdohxzepdl.mp4 -> ../../data/balanced_dataset\bdohxzepdl.mp4
